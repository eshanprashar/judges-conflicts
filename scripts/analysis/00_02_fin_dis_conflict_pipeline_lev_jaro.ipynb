# %%
# Importing libraries
import os
import pandas as pd
import jellyfish
from fuzzywuzzy import fuzz
import re
import time
from rapidfuzz.distance import Levenshtein, JaroWinkler
from collections import defaultdict

# %%
# Importing sample data
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
grandparent_dir = os.path.dirname(parent_dir)
data_dir = os.path.join(grandparent_dir, 'data/conflict/sample')
print(data_dir)
# Out:
# /Users/eshan23/eshanprashar_git_profile/judges-conflicts/data/conflict/sample

# %%
# Importing data
sample_dockets = pd.read_csv(os.path.join(data_dir, 'sampled_dockets.csv'))
print(f'The shape of the sample_dockets is {sample_dockets.shape}')
sample_investments = pd.read_csv(os.path.join(data_dir, 'sampled_investments.csv'))
print(f'The shape of the sample_investments is {sample_investments.shape}')
# Out:
# The shape of the sample_dockets is (5913, 10)
# The shape of the sample_investments is (12242, 4)

# %%
# Examine dockets sample
sample_dockets.head()
# Out:
#    author_id  judge                          docketNumber  docket_id  \
# 0       2490  Paine                          91-6548-CIV.     691131
# 1       2490  Paine  93-2123-CIV-PAINE, 94-1692-CIV-PAINE    2379325
# 2       2490  Paine                          99-10054-CIV    2371116
# 3       2490  Paine                         98-10060-CIV.    2369251
# 4       2490  Paine            99-10054-CIV-PAINE/VITUNAC    2368734
#
#                                              snippet  \
# 0  \n795 F.Supp. 1112 (1992)\nChristina Elisabeth...
# 1  \n127 F.Supp.2d 1239 (1999)\nDICTIOMATIC, INC....
# 2  \n104 F.Supp.2d 1368 (2000)\nElizabeth J. NEUM...
# 3  \n42 F.Supp.2d 1344 (1999)\nDeborah K. BRANDT,...
# 4  \n280 F.Supp.2d 1367 (2003)\nElizabeth J. NEUM...
#
#                                             caseName   dateFiled  \
# 0      Watchorn Ex Rel. Christenson v. Town of Davie  1992-08-07
# 1  Dictiomatic, Inc. v. United States Fidelity & ...  1999-06-15
# 2                   Neumont v. Monroe County Florida  2000-06-21
# 3                    Brandt v. Weather Channel, Inc.  1999-03-18
# 4                  Neumont v. Monroe County, Florida  2003-05-21
#
#                         party_1                                party_2  \
# 0  Watchorn Ex Rel. Christenson                          Town of Davie
# 1             Dictiomatic, Inc.  United States Fidelity & Guaranty Co.
# 2                       Neumont                  Monroe County Florida
# 3                        Brandt                  Weather Channel, Inc.
# 4                       Neumont                 Monroe County, Florida
#
#    dateFiled_year
# 0            1992
# 1            1999
# 2            2000
# 3            1999
# 4            2003

# %%
# From the columns above, we only need author_id, judge, docketNumber, docket_id, party_1, party_2, and dateFiled_year
columns_to_keep = ['author_id', 'judge', 'docketNumber', 'docket_id', 'caseName','party_1', 'party_2', 'dateFiled_year']
sample_dockets_reduced_v1 = sample_dockets[columns_to_keep]

# Because investment data is available for years 2002 onwards, we will only keep dockets from 2002 onwards
sample_dockets_reduced_v1 = sample_dockets_reduced_v1[sample_dockets_reduced_v1['dateFiled_year'] >= 2002]
print(f'The shape of the reduced dockets sample is {sample_dockets_reduced_v1.shape}')
sample_dockets_reduced_v1.head()
# Out:
# The shape of the reduced dockets sample is (2094, 8)
#    author_id                judge                              docketNumber  \
# 4       2490                Paine                99-10054-CIV-PAINE/VITUNAC
# 5       2490                Paine                              04-80543-CIV
# 6       2490                Paine                              03-80590-CIV
# 7       2490       Paine, Vitunac  99-10054-CIV-PAINE, 99-10054-CIV-VITUNAC
# 8       2490  Paine, Lynch, Unite                     0214160CIVPAINE Lynch
#
#    docket_id                             caseName  party_1  \
# 4    2368734    Neumont v. Monroe County, Florida  Neumont
# 5    2358425        Bazile v. Lucent Technologies   Bazile
# 6    2335767  Fick v. Metropolitan Life Insurance     Fick
# 7    2312588    Neumont v. Monroe County, Florida  Neumont
# 8    2297969   Wall v. Pennzoil-Quaker States Co.     Wall
#
#                        party_2  dateFiled_year
# 4       Monroe County, Florida            2003
# 5          Lucent Technologies            2005
# 6  Metropolitan Life Insurance            2004
# 7       Monroe County, Florida            2002
# 8   Pennzoil-Quaker States Co.            2004

# %%
# Create a dataframe with just party names
columns_to_keep = ['party_1','party_2']
sample_dockets_reduced_v2 = sample_dockets_reduced_v1[columns_to_keep]

# Merge the two columns, drop duplicates and create a list
party_names = pd.concat([sample_dockets_reduced_v2['party_1'], sample_dockets_reduced_v2['party_2']])
party_names = party_names.drop_duplicates()
party_names = party_names.tolist()
print(f'The number of unique party names is {len(party_names)}')
print(party_names[:10])
# Out:
# The number of unique party names is 3002
# ['Neumont', 'Bazile', 'Fick', 'Wall', 'Sony Computer Entertainment Inc.', 'Information Resources, Inc.', 'Blanch', 'Dimich', 'Viacom International Inc.', 'Colgate-Palmolive Co.']

# %%
# Create a merged dataframe with judges and investments
# First, in the dockets file, have both party names in a single column for merging 
sample_dockets_reduced_v3 = sample_dockets_reduced_v1[['author_id','party_1','party_2','dateFiled_year']]

# Merge party names into a single column using melt
sample_dockets_reduced_v3 = sample_dockets_reduced_v1.melt(
    id_vars=['author_id','dateFiled_year'],
    value_vars=['party_1','party_2'],
    value_name='party_name')

# Reorder columns and drop duplicates
sample_dockets_reduced_v3 = sample_dockets_reduced_v3[['author_id','party_name','dateFiled_year']]
sample_dockets_reduced_v3 = sample_dockets_reduced_v3.drop_duplicates()
print(f'The shape of the melted dockets is {sample_dockets_reduced_v3.shape}')
sample_dockets_reduced_v3.head()
# Out:
# The shape of the melted dockets is (3706, 3)
#    author_id party_name  dateFiled_year
# 0       2490    Neumont            2003
# 1       2490     Bazile            2005
# 2       2490       Fick            2004
# 3       2490    Neumont            2002
# 4       2490       Wall            2004

# %%
# Now let's examine investments sample
sample_investments.head()
# Out:
#    person_id  disclosure_year  investment_id  \
# 0        568             2015      1751139.0
# 1        568             2015      1751140.0
# 2       1816             2012      1565171.0
# 3       1816             2012      1565172.0
# 4       1816             2012      1565173.0
#
#                      inv_description
# 0  Harris Bank IRA-Non Stock Account
# 1  Harris Bank IRA-Non Stock Account
# 2                    Bank of America
# 3                    Bank of America
# 4                    Bank of America

# %%
# Get a list of unique investment descriptions - these are strings we will try to match with
investment_descriptions = sample_investments['inv_description'].unique().tolist()
print(f'The number of unique investment descriptions is {len(investment_descriptions)}')
print(investment_descriptions)
# Out:
# The number of unique investment descriptions is 4102
# ['Harris Bank IRA-Non Stock Account', 'Bank of America', 'IRA #1 MORGAN STANLEY ("MS"): UBS FINANCIAL SERV., INC.', 'Ford Motor Credit Co. (Ser. Note)', 'General Motors ACB', 'DRU, INC', 'Caterpillar FNL SVC', 'Capital One Bank Glen Allen, VA CD', 'HSBC Fin. Corp.', 'BBTCop.T', 'GE Money Bank UT CD', 'M&T Capital Trust', 'PNC Capita) Trust E', 'Credit Suisse GU', 'J.P.Morgan Chase', 'American Express Credit', 'Capital Jumbo CD', 'Flagstone Bank CD', 'MORGAN STANLEY ACCOUNT: UBS FINANCIAL SERV. INC.', 'Duke Energy', 'Bristol Meyers Squibb', 'General Electric', 'Sunrise W & G', 'Hudson GO Purp B', 'Luzeme, COGOB', 'Texas Cap. Bk. CD', 'Kansas CY CLGS', 'DB Capiual T', 'Credit Suisse', 'Citigroup', 'Decutsche BK Cap Ill', 'UBS Bank USA', '1ll. Rural Bk Bd Rev Bond', 'Walgreen', 'Romeoville, IL GO', 'Wash. St. Higher Ed. Fac Bond', 'IM-IT Bond Fund 79 (Van Kampen)', 'TI. St. U. Rev. B', 'Rancho Mirage CAB', 'Harris Bank (checking)', 'Fedcrated Prime CS', 'Mass. Mut. Life Ins. (Paid Up)', 'City Univ NY', 'Bank of New York Brokerage Cash Equivalents', 'Fidelity IRA; Ginnie Mae Mutual Fund', 'Fidelity IRA Independence Fund', 'Fidelity IRA Interim Government Income Fund', 'Fidelity IRA Cash Reserves', 'HSBC IRAS', 'Jamestown, NY', 'Metropolitan Trans Auth', 'Nassau County, NY Bonds', 'City of New York Bonds', 'New York St. Environmental', 'New York State G. O. Bonds', 'NY NY Mun WTR Fin Auth', 'NY Mun WTR Fin Auth', 'NYC Health & Hospital', 'NYC Transitional Fin Auth', 'Port of Authority of NY & NJ', 'NY ST Housing Auth', 'NY Dorm', 'NYS Twy Auth', 'Pearl River NY Free School Dist.', 'Puerto Rico Commonwealth', 'William Floyd UN', 'HSBC Deposit Accounts', 'Bank of New York', 'New York Trans Fin Auth', 'Michigan Clean Water Srf', 'NYS UDC PIT', 'Florida G. O.', 'NY Thruway Fuel TX MBIA', 'Long Island Pwr, NY', 'NY Environ', 'NY Envimmntl PIT FGIC', 'NYS Thruway SVC CTRCT', 'NY UDC Per Inc TX FGIC', 'Virgin Island PFA Rum Tax', 'NY ST Thruway Svc CT', 'Mich Hosp Ascension Health', 'Houston, TX Combined Utility', 'Seacoast, FL Wtr. Swr. FGIC', 'New York TWY Fuel TX AMBAC', 'NY Dorm Mental Health FGIC', 'LS. Trust See note #)', 'F.F.S. Trust See note 81', 'HILLIARD LYONS TRUSTEE(IRA)', "Hilliard-Lyon Gov't Fd.", 'Berkshire Hathaway-B', 'Chevron', 'Exxon Mobil', 'Growth Fd. Of Amenca', 'HILLIARD LYONS TRUSTEE (JRA)-Hill iard-Lyon Govt Fd', 'New World Fd.', 'Capital Income Bldr. Fd.', 'Hillard Lyons Growth Fd', 'Bond Fd of America', 'OTHER INVESTMENTS', 'Amazon', 'American Tower Corp', 'Clorox Co.', 'Colgate Palmolive', 'Costco', 'Disney Co.', 'Generzl Elecuic Co.', 'GlaxcoSmithKline PLC*j i §', 'Goldman Sachs', 'Growth Fd Of Amenca', 'Home Depot Inc.', 'Johnson and Johnson', 'Kimberly-Clark Corp', 'Medtronic Ine', 'Merck and Co.', 'Microsoft', 'Moodys', 'Pepsico', 'Powershares Global Exch.', 'Proctor & Gambill', 'Schiumberger Lid 3m', 'US Wireless Online, Inc', 'Walgreen Company', 'TRUST- (HRH Tr)', 'Blackrock Fd.', 'GenElect', 'shares Tr', 'BPPLC ADR', 'Coca Cola Co', 'GlaxoSmithKline PLC', 'Honeywell In],', 'Johnson & Johnson', 'McGraw-Hill Co.', 'Proctor & Gamble', 'Schlumberger Ltd', 'Texas Instruments', 'ING ReliaStar Ins.Co. Universal Life Policy', 'MONY Whole Life', 'State of Israel 12 Yr 5th Indiv. Var Rate Issue Bond(9/1/06)', 'State of Israel Bond - Exp. 1/01/13', 'Templeton Dragon Fund', 'Templeton Global Small Cos Growth Fd C1 1 Mutual Fund', 'Mutual Qualified FD CL 2 Mutual Series', 'Chartlinks, L.P', 'Strips-tprp Pmt on 10.625 2015 T/Bond-8/15/2015', 'Strips Tint-US Treasury Mat. 11/15/20', 'Vanguard Windsor II Fund', 'Templeton Growth Fund Class A', 'Mutual Discovery Fund CL2', nan, 'Partnership Interest in Whitney-Humphrey Assc. (Note)', 'U.S. Savings Bonds', 'Cash Value Life Insurance', 'Excelsior Value & Rest. Fund', 'Royce Total Return Fund', 'Schwab US Treas Money Fund', 'Sound Shore Fund', 'Thomburg Value Fund CL.A', 'Westport Select Cap.CL.R', 'Schwab Value Advantage Money Fund', 'Oakmark Select', 'Wells Fargo Adv S/C ...

# %%
# Keep relevant columns in investments data
sample_investments_reduced_v1 = sample_investments[['person_id','disclosure_year','inv_description']]
# Drop duplicates
sample_investments_reduced_v1 = sample_investments_reduced_v1.drop_duplicates()

# Rename and rearrange columns
sample_investments_reduced_v1 = sample_investments_reduced_v1.rename(columns={'person_id':'author_id','disclosure_year':'dateFiled_year'})
sample_investments_reduced_v1 = sample_investments_reduced_v1[['author_id','inv_description','dateFiled_year']]
print(f'The shape of the reduced investments is {sample_investments_reduced_v1.shape}')
sample_investments_reduced_v1.head()
# Out:
# The shape of the reduced investments is (8878, 3)
#    author_id                                    inv_description  \
# 0        568                  Harris Bank IRA-Non Stock Account
# 2       1816                                    Bank of America
# 6       1380  IRA #1 MORGAN STANLEY ("MS"): UBS FINANCIAL SE...
# 7       1380                  Ford Motor Credit Co. (Ser. Note)
# 8       1380                                 General Motors ACB
#
#    dateFiled_year
# 0            2015
# 2            2012
# 6            2009
# 7            2009
# 8            2009

# %%
# Merge investments and reduced dockets data on author_id and dateFiled_year
merged_dock_inv_str_matching = pd.merge(sample_dockets_reduced_v3, sample_investments_reduced_v1, on='author_id', how='inner')
print(f'The shape of the merged data is {merged_dock_inv_str_matching.shape}')
merged_dock_inv_str_matching.head()
# Out:
# The shape of the merged data is (1456593, 5)
#    author_id party_name  dateFiled_year_x           inv_description  \
# 0       2490    Neumont              2003             BANK ACCOUNTS
# 1       2490    Neumont              2003             Wachovia Bank
# 2       2490    Neumont              2003  West Palm Beach, Florida
# 3       2490    Neumont              2003     Fidelity Fed. Bk & Tr
# 4       2490    Neumont              2003              COMMON STOCK
#
#    dateFiled_year_y
# 0              2003
# 1              2003
# 2              2003
# 3              2003
# 4              2003

# %%
# Pipeline for string matching

stopwords = ['ltd','limited','company','inc','incorporated','corporation','corp','co','llc','plc','accounts','401K','bonds','']
special_characters = ['.',',',';',':','!','?','(',')','[',']','{','}','<','>','/','\\','|','@','#','%','^','&','*','_','+','=','-','~','`','"','\'']

def preprocess_names(names_list):
    """
    Preprocess a list of names by cleaning text (lowercase, strip spaces, remove special characters).
    
    Args:
        names_list (list): List of names to preprocess.
    
    Returns:
        list: Preprocessed list of names.
    """
    processed_list = []
    for name in names_list:
        if isinstance(name, str):  # Check if it's a string
            clean_name = name.lower().strip()
            # remove numerals and special characters defined above    
            clean_name = re.sub(r'\d+', '', clean_name)
            for char in special_characters:
                clean_name = clean_name.replace(char, '')
            # remove stopwords
            clean_name = ' '.join([word for word in clean_name.split() if word not in stopwords])
            processed_list.append(clean_name)
        else:
            processed_list.append('')
    return processed_list

# %%
# Preprocess party_name and inv_description in the merged dataframe
merged_dock_inv_str_matching['processed_party_name'] = preprocess_names(merged_dock_inv_str_matching['party_name'].tolist())
merged_dock_inv_str_matching['processed_inv_description'] = preprocess_names(merged_dock_inv_str_matching['inv_description'].tolist())

# %%
# Examine merged_dock_inv_str_matching
merged_dock_inv_str_matching.head()
# Out:
#    author_id party_name  dateFiled_year_x           inv_description  \
# 0       2490    Neumont              2003             BANK ACCOUNTS
# 1       2490    Neumont              2003             Wachovia Bank
# 2       2490    Neumont              2003  West Palm Beach, Florida
# 3       2490    Neumont              2003     Fidelity Fed. Bk & Tr
# 4       2490    Neumont              2003              COMMON STOCK
#
#    dateFiled_year_y processed_party_name processed_inv_description
# 0              2003              neumont                      bank
# 1              2003              neumont             wachovia bank
# 2              2003              neumont   west palm beach florida
# 3              2003              neumont        fidelity fed bk tr
# 4              2003              neumont              common stock

# %%
# Filter out rows (names) where processed_party_name or processed_inv_description length is less than 5
merged_dock_inv_str_matching_v1 = merged_dock_inv_str_matching[
    (merged_dock_inv_str_matching['processed_party_name'].str.len() >= 5) & 
    (merged_dock_inv_str_matching['processed_inv_description'].str.len() >= 5)]

# Examine the shape of the filtered data
print(f'The shape of the filtered data is {merged_dock_inv_str_matching_v1.shape}')
print(merged_dock_inv_str_matching_v1.head())
# Out:
# The shape of the filtered data is (1326520, 7)
#    author_id party_name  dateFiled_year_x           inv_description  \
# 1       2490    Neumont              2003             Wachovia Bank
# 2       2490    Neumont              2003  West Palm Beach, Florida
# 3       2490    Neumont              2003     Fidelity Fed. Bk & Tr
# 4       2490    Neumont              2003              COMMON STOCK
# 5       2490    Neumont              2003          Loch Laurel Club
#
#    dateFiled_year_y processed_party_name processed_inv_description
# 1              2003              neumont             wachovia bank
# 2              2003              neumont   west palm beach florida
# 3              2003              neumont        fidelity fed bk tr
# 4              2003              neumont              common stock
# 5              2003              neumont          loch laurel club

# %%
# Extract unique processed_party_name and processed_inv_description
unique_processed_party_names = merged_dock_inv_str_matching_v1['processed_party_name'].unique().tolist()
unique_processed_inv_descriptions = merged_dock_inv_str_matching_v1['processed_inv_description'].unique().tolist()
print(f'The number of unique processed party names is {len(unique_processed_party_names)}')
print(f'The number of unique processed investment descriptions is {len(unique_processed_inv_descriptions)}')
# Out:
# The number of unique processed party names is 2808
# The number of unique processed investment descriptions is 3184

# %%
# Create a dictionary to store investment results alphabetically

def create_investment_dict(investment_descriptions):
    investment_dict = defaultdict(list)
    for desc in investment_descriptions:
        if isinstance(desc, str) and desc:
            first_letter = desc[0].lower()
            investment_dict[first_letter].append(desc)
    return investment_dict

# %%
# Create a dictionary of investment descriptions
processed_investment_dict = create_investment_dict(unique_processed_inv_descriptions)
processed_investment_dict
# Out:
# defaultdict(list,
#             {'w': ['wachovia bank',
#               'west palm beach florida',
#               'walgreen',
#               'wash mutual',
#               'world com',
#               'wachovia bank was first union’ common stock',
#               'wachovia bank was first union common stock',
#               'wells fargo common stock',
#               'wells fargobanks',
#               'wachovia bank meger with wells fargo',
#               'wells fargo',
#               'wells fargo new del',
#               'walmart',
#               'wachovia',
#               'walgreens',
#               'washington mut',
#               'wyeth formerly amer home prod',
#               'wyeth formerly amerhome prod',
#               'walt disney',
#               'walgreens oo',
#               'waddell reed',
#               'wachovia new',
#               'walmart stores',
#               'weatherford intl',
#               'wal mart stores',
#               'wrigley wm jr',
#               'whole foods mkt',
#               'washington sub sanit',
#               'winchester va',
#               'whiting pete',
#               'wisconsin energy',
#               'wabtec',
#               'waters',
#               'whiting petroleum',
#               'weatherford intlltd',
#               'wells fargo advisors no control includes',
#               'wells fargo advisors tactical etf',
#               'wells fargo advisors fundsource',
#               'wells fargo advisors tactical etf no control',
#               'wells fargo advisors fundsource no control',
#               'wells fargo bank lincoln ne cash',
#               'wash st higher ed fac bond',
#               'western union',
#               'wells fargo pfd',
#               'western umon',
#               'wachovia pf',
#               'washington bankcd',
#               'wsbank of china cd',
#               'wells fargo money market fund',
#               'wachovia money market fund',
#               'william floyd un',
#               'walgreen boots alliance merged with walgreen',
#               'walgreens boots alliance merged with walgreen',
#               'westport select capclr',
#               'wells fargo adv sc value z',
#               'wells fargo adv smallmidcap value fund',
#               'wells fargo advantage value fund',
#               'westport select cap clr',
#               'westport select capclr fund note',
#               'wells fargo adv small cap value z fund note',
#               'wells fargo adv smallmidcap value fu nd',
#               'westport smcapclr',
#               'westport sm cap class r',
#               'walmart common x',
#               'wells fargo checking account x',
#               'wells fargo certificates of deposit x',
#               'wells fargo cd ira',
#               'wells fargo cdira',
#               'wellsfargo',
#               'wellsfargocd',
#               'wells fargo money market',
#               'wells fargo checkingsavings',
#               'wells fargo brokerage',
#               'wells fargocd',
#               'wells fargo brokerage cash equivalent',
#               'wellsfargo cd ira',
#               'wells fargo cd',
#               'wflls fargo money market',
#               'whirlpool f’ka maytaag',
#               'walmart de cv spn adr f',
#               'windstream spin off from alltel',
#               'whirlpool fka maytaag',
#               'walmart de cv spn adrf',
#               'wells fargo account',
#               'wells fargo bank x',
#               'walmait de cv spn adr f',
#               'walmart de cvspn adr f',
#               'waukee state bank',
#               'wells fargo new',
#               'west bank',
#               'walmaurt de cv spn adr f',
#               'windstream zpin off from alltel'],
#              'f': ['fidelity fed bk tr',
#               'first data',
#               'fresno cal pension rev zero coupon',
#               'fed home loan bank',
#               'franklin templeton corefolio allocation fu nd',
#               'franklin templeton corefolio allocation fund',
#               'fixib sy tedr tips tdtf',
#               'fixib sy tgdr tips tdtf',
#               'financial select sector spdr fund xlf',
#               'fix ib sy tgdr tips tdtf',
#               'first trust low duration bond',
#               'first citizens bank deposit',
#               'family dollar stores common',
#               'first citizens bank deposit x',
#               'filial amor common stock',
#               'filial amor',
#               'first pr tax eexmpt fd pg',
#               'fixed rate note a y',
#               'first pr tax exempt fd pfd',
#               'first pr¥tax exempt fd pfd',
#               'filial amor corpcommon stock',
#               'firstrust checking accts',
#               'firstrust savings',
#               'firstrust combined savings',
#               'first union',
#               'firstrust bank checking',
#               'firstrust bank savings',
#               'first trust unit',
#               'fil rstrust bank checking',
#               'firstrust unit',
#               'first trust unit gum',
#               'firstrust int rate hedge',
#               'firstrust s lid',
#               'firstrust div e fd',
#               'ffs trust see note',
#               'ffs trust see note ¥',
#               'fidelity mon mark institutional class',
#               'fidelity mon mkt',
#               'fidelity advisor fd',
#               'fidelity mon mark',
#               'ffs trust',
#               'first marblehead',
#               'federated automated govt money trust',
#               'fed natl mtg assn',
#               'fed home ln mtg',
#               'fed home ln bk',
#               'fed farm credit',
#               'french disc t bill',
#               'forest labs',
#               'fed home loan mtg',
#               'fairfax cnty va redev',
#               'fairfax cnty va',
#               'fairfax cnty',
#               'first va bank falls church',
#               'fifth third bancorp',
#               'federated dept stores',
#               'factset resh sys',
#               'fisher scientific intl',
#               'federated invs',
#               'federated investores',
#               'factset research systems',
#               'fefderated dept stores',
#               'federal home loan bank',
#               'federated prime obligations fdss',
#               'fed farm cr bk',
#               'fair isaac',
#               'fiserv',
#               'federated automated govt money trust ¢',
#               'fairfaxcnty',
#               'fedl natl mtg assn',
#               'fhlmc',
#               'fairisaac',
#               'fairpoint communications',
#               'fmc new',
#               'fedex',
#               'flowserve',
#               'fhlb cons disc',
#               'fpl group',
#               'fnma disc',
#               'fhlmc mtn',
#               'fastenal',
#               'fedhomeloanbank',
#               'fed home loan bank »',
#               'freeport mcmoran copper b',
#               'formfactor',
#               'federal home loan bk disc',
#               'fhlb »',
#               'freeportmcmoran copper gold',
#               'form factor',
#               'federal home loan bank disc',
#               'fhlb disc',
#               'ffx cnty va',
#               'farm equipment',
#               'federal judicial credit union',
#               'federaljudicialcredit union',
#               'ford motor credit ser note',
#               'flagstone bank cd',
#               'fedcrated prime cs',
#               'freeportmcmoran fcx',
#               'first energy fe',
#               'first energy',
#               'first energy comp fe',
#               'ford motor credit nts',
#               'ford motor credit',
#               'fayette school district',
#               'fl mun council',
#               'ford motor credit see note',
#               'first credit union of scranton',
#               'fidelity ira ginnie mae mutual fund',
#               'fidelity ira independence fund',
#               'fidelity ira interim government income fund',
#               'fidelity ira cash reserves',
#               'florida g o',
#               'first manhattan cash cash equivalents',
#               'first manhattan rollover ira',
#               'ficellty tra',
#               'fidelity ira',
#               'fidelity cash acct',
#               'franklin mutual quest fund',
#               'fairholme fund',
#               'farrholme fund',
#               'fidelity cash account note',
#               'franklin mutual quest fund note',
#               'franklin sm mid cap gr fund class a',
#               'franklin high yield tx free class a xx',
#               'first american bank fka waukee state bank',
#               'fidelity adv serv vii technology fd ci t',
#               'fidelity adv eqty growth fund',
#               'fidelity adv overseas class t',
#               'franklin biotechnology discovery fund',
#               'ford motor',
#               'farming operation crops',
#               'farm dallas ia',
#               'farm adair ia',
#               'fann adair ia',
#               'farm adams ia',
#               'farm taylor county',
#               'farm decatur county',
#               'fidelity adv serv vii technology fd c t',
#               'farm dallas a',
#               'farm dallas la',
#               'farm adams a',
#               'frontier communicationsspin off from verizon',
#               'famm dallas ia',
#               'farm decatur county ia',
#               'fidelity explorroyalty bowman nd',
#               'farm s adair ia',
#               'farm taylor county ia',
#               'farm decatur county la',
#               'farm s adair a',
#               'farm adair a',
#               'farm adams la',
#               'farm taylor county a',
#               'farm decatur county a',
#               'fiserv fisv',
#               'ford motor f',
#               'farm s$ adair ia',
#               'fidelity explorrovalty bowman nd',
#               'first date fdc',
#               'flextronics int flex',
#               'ford f',
#               'first data fdc',
#               'facebook fb',
#               'farm adair lowa y',
#               'farm adair iay',
#               'farm adair ay',
#               'farm adams iay',
#               'farm taylor county ia y',
#               'fidelity adv serv vii technology fd cit',
#               'farming operation',
#               'farm dallas ia sold as lots',
#               'first solar fslr',
#               'fidelity adv serv vii technology fci t',
#               'fidelity ady overseas class t',
#               'farming operation crops ad',
#               'farm dallas ja',
#               'furm dallas ia',
#               'funn aduir ia ¢ oo so',
#               'fann adair a',
#               'farm adair ia nx',
#               'fumm adair a farm adair ia farm adums a farm s adams a farm adams ia',
#               'furm taylor county',
#               'farm dceatur county',
#               'farm $ adair ia'],
#              'c': ['common stock',
#               'commercial property wpb',
#               'cubic',
#               'cisco',
#               'coming',
#               'conocophillips',
#               'costco',
#               'corning',
#               'coach',
#               'cubic tt',
#               'chase bank account',
#               'citibank',
#               'chase bank',
#               'cash or equivalent',
#               'camival paired saa ccl',
#               'cme group cme',
#               'coca cola ko',
#               'charles schwab investments',
#               'carmival paired saa ccl',
#               'carmival paired shs saa ccl',
#               'chevron',
#               'cme group',
#               'cisco systems com',
#               'coca cola com',
#               'crown castle reit',
#               'carnival paired shs',
#               'carrier global reg sh',
#               'chubb',
#               'citigroup com',
#               'carnival paired shs s',
#               'camuval paired shs s',
#               'carmuval paired shs s',
#               'carval paired shs s',
#               'camival paired shs s',
#               'carmval paired shs s',
#               'chubb ld',
#               'crucell n v spon adr inis',
#               'cres undeveloped land wilkes cnty assess $',
#               'crucell nv spon adr inis',
#               'cash in bank scotiabank x',
#               'common stock in conagra food',
#               'common stock in cibc mellon trust',
#               'caribe federal credit union cash in bank',
#               'common stock in metlife',
#               'common stocks in metlife',
#               'common stock in conagra foods',
#               'canbbean pensions money purchase plan',
#               'cash in bank scotiabank',
#               'cash in bank banco popular',
#               'cash balance ubs bank',
#               'cash balance',
#               'common stock in cibc mellon trlst',
#               'caribe federal credit union',
#               'calamos global dynamic',
#               'claymore securities defined portfolios y',
#               'claymore closed end',
#               'claymore securities defined portfolios',
#               'claymore securities defined to ios',
#               'capital income bldr fd',
#               'clorox',
#               'colgate palmolive',
#               'coca cola',
#               'cincinnati fin',
#               'cincinnati fincorp',
#               'chevron ®',
#               'charitable foundation h',
#               'capital builder',
#               'compass bankshares',
#               'citigroup',
#               'cocacola',
#               'compass bksh',
#               'computer services',
#               'charitable foundation jib',
#               'cash equiv fd',
#               'colgate palmolive b',
#               'citadel broadcasting',
#               'charitable foundation ml fd',
#               'chevron comp',
#               'common stocks',
#               'chevrontexaco',
#               'caterpillar',
#               'columbia acorn trust',
#               'cisco sys',
#               'cooper cos',
#               'community health sys',
#               'celgene',
#               'cognos',
#               'cott que',
#               'citibank mda short term',
#               'community health systems',
#               'cisco systems',
#               'chesterfield cnty va',
#               'cintas',
#               'clarcor',
#               'c h robinson worldwide',
#               'cumberland cnty',
#               'charles riv labs',
#               'columb ia acorn trust',
#               'commonstocks',
#               'charlottesville',
#               'choicepoint',
#               'citrix sys',
#               'cameron intl',
#               'cytec inds',
#               'charles riv labs intl',
#               'carpenter technology',
#               'carter',
#               'chesapeake energy',
#               'columbia value restr fund',
#               'citrix systems',
#               'cameron international',
#               'cytec industries',
#               'carpenter tech',
#               'carters',
#               'ciscosystems',
#               'canon',
#               'church dwight',
#               'canadian national railway',
#               'cr bard',
#               'common stocksmutual funds',
#               'chevrontexacocorp',
#               'cardinal health',
#               'ciscosys',
#               'cobblestone square partnership',
#               'checking accountsuntrust bank',
#               'checking accountrivoli bank trust',
#               'citibank na bank deposit program',
#               'checking accountsecurity bank fka rivoli bank trust',
#               'checking accountatlantic southern bank',
#               'checking account suntrust bank',
#               'checking account rivoli bank trust',
#               'capital group international equity sma',
#               'clear bridge investments all cap growth',
#               'capital group intemational equity sma',
#               'capital world bond',
#               'charles schwab bank roth ira cash',
#               'charles schwab stock ira disney credit suisse asset manag',
#               'caterpillar fnl svc',
#               'capital one bank glen allen va cd',
#               'credit suisse gu',
#               'capital jumbo cd',
#               'credit suisse',
#               'cliffs nat res clf',
#               'credit suisse gl',
#               'chi bd ed',
#               'chicago intl arpt bond',
#               'cml urevoid',
#               'clark city new appt r',
#               'cmiurevoid',
#               'clark city new ap r',
#               'citizens ppty ins c fl',
#               'capital one bank glen allen vacd',
#               'cmil urevoid',
#               'c mil u rev oid',
#               'cml u revs oid',
#               'clark city nev appt r',
#               'city univ ny',
#               'city of new york',
#               'cash equivalents first manhattan',
#               'conocophillips com',
#               'cash equivalents first manhattan bank',
#               'crimson wine group spinoff from leucadia national',
#               'crimson wine group com spin off from leucadia',
#               'cash equivalents',
#               'cityof new york',
#               'crimson wine group',
#               'city tmiv yy',
#               'city oi vy oncs',
#               'city o yy oncs',
#               'city of ny oncs',
#               'cash equivalentsfirst manhattan',
#               'city univny',
#               'cash reserves',
#               'chartlinks lp',
#               'cash value life insurance',
#               'citizens bank',
#               'calamos growth fund a',
#               'cmg focus fund',
#               'cmg realty fund',
#               'columbia value rest fund',
#               'conoco philips',
#               'crown life ins whole hic policy',
#               'citizens bank note',
#               'calamos growth fund a note',
#               'chanrlinks lp',
#               'crown life ins whole life policy',
#               'columbia value rest fund note',
#               'calamos',
#               'calamos growth fund',
#               'cabot comp',
#               'coca cola com hil',
#               'centl sowest',
#               'cabot x',
#               'cabot stock',
#               'ca interm tx exempt fund x',
#               'ca tx exempt money mkt x',
#               'columbia high yield municipal fund',
#               'columbia managed municipal fund taxexempt fund z',
#               'ca interm tx exemp tfund x',
#               'columbia managed municipal fund',
#               'columbia municipal money market',
#               'citibank west fsb accts',
#               'citibankwestfsb accts',
#               'citibankwest fsb accts',
#               'csco stock',
#               'chicos fas',
#               'corrections cp amer new',
#               'capital world growth income fd cl a american funds',
#               'cincinnati life insurance whole life policy',
#               'carefree group',
#               'commerce bancshares ia',
#               'constellation energy',
#               'corrections am',
#               'capmark bank cd',
#               'commerica bank cd',
#               'canam uranium',
#               'cleanpathres',
#               'conocophilips',
#               'corrections cp amer',
#               'covidien',
#               'csco suck',
#               'canadian oil coswf',
#               'centerpoint energy cnp',
#               'cmcmmati bell cbb',
#               'cvs caremark cv',
#               'cleanpath resources clnp',
#               'constellation energy ceg',
#               'corrections am cxw',
#               'carlyle grp cg',
#               'citigroup cit',
#               'cleanpath resources clnpy',
#               'crowncastle ccl',
#               'cytokinetics cytk',
#               'calm ent ep',
#               'caterpillar cat',
#               'cliffs natural resources clf',
#               'crocs crox',
#               'cyrokinetics cytk',
#               'continental resources x',
#               'citigroup c',
#               'crestwood mid lpcmlp',
#               'cadence pharm cadx',
#               'croce crox',
#               'cvs caremark',
#               'capmark bank na',
#               'commercial bank na',
#               'cocacola cce',
#               'cray computer',
#               'commerce bancshares a',
#               'chemtura chmt',
#               'cytokmetics ine cytk',
#               'career education ceco',
#               'cgm mutual fund',
#               'cliffs nat resources',
#               'chffs natural resources clf'],
#              'l': ['loch laurel club',
#               'lake toxaway nc house',
#               'lowes',
#               'lennar',
#               'lockheed',
#               'liny pwr auth elec sys series a zero coupon',
#               'li ny pwr auth elec sys series a zero coupon',
#               'lucent common stock',
#               'lockheed martin lmt',
#               'lockheed martin',
#               'lowes companies common',
#               'lusaa subscriber account x',
#               'lehman bros grantor tr mgt tr',
#               'law firm adsuar muniz goyco besosa psc stock',
#               'lehman bros grantor tr mtg tr',
#               'life strategy mod growth ira',
#               'lord abbett all value',
#               'life strategy growth fund',
#               'life strategy mod growth',
#               'life strategy mod growth eerie eererer— star fund',
#               'lord abbett affiliated fund',
#               'ly udson bank',
#               'lord abbett all value gil',
#               'ls trust see note',
#               'lord abbett fd',
#               'ls trust see note £',
#               'ls trust',
#               'lord abbett af fd',
#               'ls tost',
#               'lynchburg va',
#               'loudoun cnty var',
#               'lexmark intl group',
#               'lowes cos',
#               'lehman bros hldgs',
#               'lamar advertising',
#               'lexmark intl',
#               'lehman bros',
#               'liberty acorn trust',
#               'llinok tool works',
#               'lowes cos rr e——————————————————— kohls sis microsoft',
#               'lfoberdorfer agency acct',
#               'lincoln national',
#               'legg mason partners fds',
#               'loudouncnty va',
#               'los id',
#               'lf oberdorfer agency acct',
#               'loudoun cnty va',
#               'luzeme cogob',
#               'll rural bk bd rev bond',
#               'lstlu rev b',
#               'lll st u rev b',
#               'lcredit suisse gu',
#               'lorraine city ohio health frcp',
#               'luzerne go',
#               'loraine cty oh health frcp',
#               'luzerne cogo b',
#               'lee city fl impt',
#               'las vegas imp d',
#               'lehman brothers bank fsb wilmington decd',
#               'lorraine city ohio health fricp',
#               'luzernecogb',
#               'lasalle bankclare residency escrow',
#               'lll rural bk bd rev bond',
#               'lllst u rev b',
#               'luzerne gb',
#               'lorraine cty ohio health frcp',
#               'lord abbett affiliated mutual fund',
#               'long island pwr ny',
#               'leucadia national',
#               'loews',
#               'leucadia natl',
#               'lightstream res lid note',
#               'lucent technologies',
#               'lord abrbett affil fund',
#               'lord abbett affil fund',
#               'legg mason partners aggressivegrowth',
#               'legg mason partners aggressive growth',
#               'legg mason partners aggress ive growth',
#               'liberty bank account',
#               'l t v',
#               'laserscope',
#               'level communications',
#               'lucent techs warrants',
#               'laudus equity fund',
#               'liberty banshares incappraisal',
#               'ltc properties',
#               'laudus intl equity',
#               'lowa telecommunications',
#               'ltau unibanco holding sa tyb',
#               'level communications lvlt',
#               'liberty banshares y',
#               'lsc communications lksd',
#               'lam research lrcx',
#               'lumentum holdings lite',
#               'lsi lsi',
#               'ltau unibanco holding sa',
#               'lions gate entmet lgf',
#               'l t v new',
#               'lcahn ent iep',
#               'lazard emerging markets',
#               'level commumecanons',
#               'lusudus equity fund',
#               'lsc commumcations lksd'],
#              'j': ['jp morgan chase',
#               'johnson johnson',
#               'jp morgan chase jpm',
#               'johnson and johnson com',
#               'jackson natl life ins whole life policy',
#               'jackson natl life lus whole life policy d',
#               'jackson natl life ins whole life policy see viii',
#               'jackson natl life ins whole hfe policy see vid',
#               'jackson natl lite ins whole hie policy d',
#               'jackson national life ins whole life policy',
#               'jackson national lite ins whole hie policy',
#               'jackson national life ins whole life policy x',
#               'jgnma unit',
#               'judicial retirees survivors',
#               'johnson and johnson',
#               'jp morgan',
#               'johnsson and johnson',
#               'jefferson pilot',
#               'joy global',
#               'j p morgan chase',
#               'jp morgan large cap',
#               'jp morgan large cap core plus',
#               'jacobs engr group',
#               'jennison associates large cap value equity sma',
#               'justice federal credit union',
#               'judicial federal credit union',
#               'jackson national life perspective ii fixed and variable annuity h',
#               'jnldoubleline corefxdinc',
#               'jnlppm america high yieldbd',
#               'jnlcore plus bond',
#               'jnl america growth',
#               'jnlmc sm cap index',
#               'jnltrowe price midcapegr',
#               'jnlblack rock glbl alloc',
#               'jackson national life perspective il fixed and variable annuity h',
#               'jpmorgan chase',
#               'jp morgan deposit account b',
#               'jpmrf',
#               'jipmprg',
#               'jp morgan dep ac b',
#               'jennings ind sch',
#               'jennings ind sch hudson go purp b allengob',
#               'jtramsdwus govsecb',
#               'jennison utility fund class a',
#               'janus investment worldwide mutual fund',
#               'john hancock global tech fund',
#               'jennison uulity fund class a',
#               'jamestown ny',
#               'johnson johnson com',
#               'johnson johmson common',
#               'johnson johnson common',
#               'jensen portfolio',
#               'jp morgan bond fund ira',
#               'jp morgan trust core bond fund',
#               'janus twenty fund',
#               'jabil circuit',
#               'johnson controls',
#               'jabil circuit ub',
#               'johnson controls jci',
#               'johnson johnson jnj',
#               'jabil circuit ubl',
#               'jetblue jbll',
#               'jabil circuit jbi',
#               'johnson controlsjci',
#               'jp morgan chase jbl',
#               'jabil circuit jbl'],
#              'r': ['real estate',
#               'rinker',
#               'rayonier common stock',
#               'ratheon common stock',
#               'rental property new britain pa',
#               'rental property new bntain pa',
#               'rental property enr pa',
#               'rental property nee pa',
#               'rental property doylestown pa',
#               'rental property gg pa',
#               'rental property ir pa',
#               'rental property pum pa',
#               'rental property',
#               'rental property ‘ui pa',
#               'roval dutch shell spons adrb rds',
#               'royal dutch shell spons adr b',
#               'raytheon technologies',
#               'royal bank canada pv$',
#               'royal dutch shel',
#               'roval dutch shel',
#               'reassure amer life ins whole life policy see viit',
#               'receivable from asuar muniz goyco besosa psc',
#               'recervaly€ rom amummmeumm pe————',
#               'renal property hallandale fl',
#               'rh bumbey inv',
#               'rh bumhey inv',
#               'royce opportunity fd',
#               'rovce fd',
#               'rh burnhey invest',
#               'rh burnhey inv',
#               'royce fd',
#               'roanoke va',
#               'richmond va',
#               'riggs national bank washington dc',
#               'royal dutch pete',
#               'riggs natl bank washington dc',
#               'real estatesee part viii for assessment data',
#               'royal dutch shell',
#               'ralcorp hldgs',
#               'ralcorp holdings',
#               'rpm ohio',
#               'regions financial',
#               'rpm intl',
#               'real estatf a',
#               'riggs money mkt',
#               'riggs bank money market',
#               'rf micro devices',
#               'red hat',
#               'research in motion',
#               'richmond va pub impt',
#               'roper inds',
#               'rockwell collins',
#               'regal beloit',
#               'rivoli bank trust stock',
#               'rome savings bank rome ny',
#               'rbc capital retirement account no control includes',
#               'rone savings bank rome ny',
#               'rbc capital retirement account no control',
#               'rbc capital retirement account',
#               'romeoville il go',
#               'rancho mirage cab',
#               'royal dutch',
#               'rancho mirage ca b',
#               'roval dutch',
#               'rma money mkt',
#               'rural bk bd rev bond',
#               'romeoqville il g unltd',
#               'robertson stephens inv trust emerging growth fund',
#               'rhj international common',
#               'rhj intemational common',
#               'range res',
#               'range res com',
#               'rh international common',
#               'roociaven y',
#               'rhij international common',
#               'royce total return fund',
#               'royce value fund',
#               'rovce total return fund',
#               'rovee value fund',
#               'royce total retum fund',
#               'roval bank of canada ira account',
#               'roval bank of canada prime money market',
#               'royal bank of canada ira',
#               'ranch reed',
#               'reed mfg common stock',
#               'reed mfg note receivable',
#               'reed mfg inccommon stock',
#               'retirement account',
#               'royalty interest bowman county north dakota',
#               'reliance steel aluminum',
#               'renhe commercial hldg',
#               'reliance steel aluminumrs',
#               'renhe commercial hidg rnhef',
#               'rosetta resources rose',
#               'roval dutch shell rdsa',
#               'retirement account h',
#               'rrdomnelley rrd',
#               'royal dutch shell rdsa',
#               'renhe commercial hldg rnhef',
#               'repligen rgen',
#               'ruby tuesday rt',
#               'rouse pptys rse',
#               'real industry rely',
#               'ryman hosp rhp'],
#              'a': ['am int group',
#               'anheuser busch',
#               'amgen',
#               'as trustee of trust fed strips',
#               'arlington ny cent schl dist series b due',
#               'alcatellucent',
#               'att common stock',
#               'astrazeneca azn',
#               'amencan electric power aep',
#               'abbvie shs',
#               'air products chemicals',
#               'american electric power aep',
#               'amgen com',
#               'astrazeneca spnd adr',
#               'american electric power',
#               'abbwvie shs',
#               'abbwie shs',
#               'amenican electric power',
#               'acres undeveloped land wilkes cnty nc assess $',
#               'acres undeveloped land beaufort cnty nc assess $',
#               'acres undeveloped land wilkes cnty nc assessed value $',
#               'acres undeveloped land beaufort cnty nc assessed value $',
#               'acres undeveloped land beaufort canty nc assessed value $',
#               'account receivable from adsuar muniz goyco besosa psc',
#               'alliance bernstein cap reserve',
#               'alliance bemnstein cap reserve',
#               'att wireless savio',
#               'alliance bemstein cap reserve',
#               'advisors disciplined tr unit',
#               'american savingsnow first union',
#               'amazon',
#               'american tower',
#               'artisan midcap',
#               'artisan midcap value fd',
#               'allergan',
#               'american europacific fd',
#               'american european gr fd',
#               'american fds new world fd',
#               'amencan growth fd',
#               'american small cap fd',
#               'armanda',
#               'amencan tower',
#               'apple',
#               'a growth fd of america',
#               'american int group',
#               'american intl group',
#               'a hilliard lyons growth',
#               'altria',
#               'altna',
#               'applied makenals',
#               'a hilhard lyons growth',
#               'amencan europacific fd',
#               'american growth fd',
#               'amencan small cap fd',
#               'archstone smith trust',
#               'anadarko pete',
#               'automatic data processing',
#               'aggregate see note part viii',
#               'amsouth bancorp',
#               'adobe sys',
#               'analog devices',
#               'anheuser busch cos',
#               'avaya',
#               'avon prods',
#               'applied materials com',
#               'affymetrix',
#               'allegheny technologies',
#               'associated banc',
#               'avery dennison',
#               'allstate com',
#               'ace cayman',
#               'anntaylor stores',
#               'altria group',
#               'american express',
#               'ameriprise financial',
#               'applied materials',
#               'ace ord',
#               'aceltd ord',
#               'allstate',
#               'aggregateseenote part viii',
#               'aggregatesee note part viii',
#               'aggregatesee note part vii',
#               'abbott labs',
#               'autozone',
#               'affiliated computer svcs',
#               'aflac',
#               'adobe systems',
#               'aggregate for of trustssee note part viii',
#               'arlington cnty',
#               'automated data processing',
#               'att wireless',
#               'automatic data processng',
#               'american pwr convers on cor',
#               'advance auto parts',
#               'atheros communications',
#               'arch coal',
#               'applera',
#               'applied biosys',
#               'alpha nat res',
#               'americanexpress',
#               'applera corps',
#               'applied biosystems',
#               'amphenol',
#               'al wtr poll',
#               'automatic data processing i nc',
#               'archer daniels midland',
#               'ala wtr poll',
#               'atheros communication',
#               'ann taylor stores',
#               'arlington va',
#               'apache',
#               'ametek new',
#               'ametek',
#               'archstone smith tr',
#               'arch capital group',
#               'ambac financial grp',
#               'american bar association retirement plan keough',
#               'american funds capital world mutual fund',
#               'americu credit union',
#               'apex capital all capgrowth sma',
#               'amencan funds capital world mutual fund',
#               'amencu credit union',
#               'apex capital lcg',
#               'amencu prime share',
#               'amercu prime share',
#               'axaequitable life insurance annuity contractira h',
#               'axaequitable life insurance variable lifeincentive life h',
#               'axa moderate allocation',
#               'axaequitable life insurance annuity contractiranh',
#               'alliance growth mutual fund class b secacus nj',
#               'axaequitable life insurance variable lifelncentive hy',
#               'american express credit',
#               'anglogod ashanti hldgs',
#               'allen go',
#               'advanta bankcd',
#               'allengob',
#               'allegheny energy',
#               'american elec power',
#               'aim weingarten mutual fund',
#               'ascent cap group',
#               'american express common',
#               'allison transmission',
#               'ascent media ser a',
#               'amstercam y oncs',
#               'amestown vy',
#               'anz ° vew york',
#               'artisan intl small cap',
#               'ariel apprec fund',
#               'arcadia wind fanns energies',
#               'axa equitable life ins hfe policy',
#               'artisan intl small cap investor',
#               'arcadia wind farms energies',
#               'alphabet',
#               'amr com',
#               'axa equitable life ins life policy',
#               'axa equitable life ins flexible premium universal life policy',
#               'aig focused div strategy note',
#               'aig focused div strategy',
#               'arusan intl small cap',
#               'artisian mid cap value fund',
#               'arcadia wind farms energies lud',
#               'artisan intl small cap note',
#               'aim weingarten clb fund',
#               'artisan intl small cap fund',
#               'artisan midcap value fd note',
#               'aim weingarten clb',
#               'agere sys',
#               'amn elec power',
#               'albertson',
#               'albertsons',
#               'att x',
#               'att stock',
#               'am century inv growth funds x',
#               'am funds fundamental inv class a x',
#               'att common x',
#               'axa financial common stock',
#               'american cent ultra fundvalic',
#               'agere systems',
#               'alltel units',
#               'american tech grp',
#               'applenew',
#               'associated banc wis',
#               'authentidate hldg',
#               'avayalinc',
#               'audible',
#               'aerovironment',
#               'amedisys',
#               'ameritrade holding',
#               'annaly capital mgmt reit',
#               'aolspinoff from time warmer',
#               'aviva',
#               'amercian century opportunity kopp emerging growth fund',
#               'annaly cap mgmt reit',
#               'altnia group',
#               'access accp',
#               'allstate all',
#               'altria group mo',
#               'amedisys incamed',
#               'ameriprise financial amp',
#               'ameritrude holding amtd',
#               'annaly capital mgmt reit nly',
#               'apple appl',
#               'arm holdings armh',
#               'abeonatherapeutics abeo y',
#               'air canada acdvf',
#               'american airlines aal',
#               'american intl grp aig',
#               'applied materials amat',
#               'alamos gold agi',
#               'aurico metals arctfxy',
#               'american airlines grp aal',
#               'altra group mo',
#               'alamos gold agh',
#               'axon enter aaxn formerly taser',
#               'amencan airlines grp aal',
#               'ageniusagen',
#               'apache apa',
#               'auricogold auq',
#               'aecom tech acm',
#               'arm holdings',
#               'authentidate hidg',
#               'abbot lab abt',
#               'alliance resource arlp',
#               'amt tat',
#               'american cent ultra fund',
#               'abeonatherapeutics abeo formerly known as plasmatech ptbi',
#               'amencan airlmes aal',
#               'auricogold ine auq now alamos gold agh',
#               'aurico metals arctf',
#               'abtec',
#               'abeona abeo',
#               'abeona therap abeo',
#               'at t t',
#               'agere systems ine',
#               'allianz nacm pucific rim',
#               'amencan intl group',
#               'allee del',
#               'associuted banc wis',
#               'authentidute hldg',
#               'avaya lnc',
#               'amercian centiry opportunity kopp emerging growth fund',
#               'allianz nacm pacific rim',
#               'alltel del',
#               'applied materiasls amat',
#               'auricogold alq',
#               'at tt',
#               'agenus agen',
#               'ally financial ally',
#               'amc enter amc'],
#              'p': ['pfizer',
#               'proctor gamble',
#               'paychex',
#               'pepsi',
#               'phizer',
#               'proctar gamble',
#               'phizer common',
#               'pfizer common',
#               'pnc bancorp common stock',
#               'prescient medical',
#               'property yr',
#               'phzer',
#               'pnc bancorp common stack',
#               'property eer pa',
#               'paccar pcar',
#               'ppl ppl',
#               'philip morris intl pm',
#               'phzer pfe',
#               'proctor gamble pg',
#               'pimco year high yield corporate bond index exchangetraded hys',
#               'powershares optimum yield diversified commodity strategy no k pdbc',
#               'powershares senior loan etf bkln',
#               'pfizer pfe',
#               'powershares db agriculture fund dba',
#               'powershares db base metals fund etf dbb',
#               'powershares db onl fund etf dbo',
#               'powershares db oil fund etf dbo',
#               'pimco year high yield corporat bond index exchangetraded hys',
#               'paccar',
#               'philip morris international',
#               'phizer ne',
#               'procter gamble',
#               'pimco year hy bond',
#               'pepsico',
#               'pr commonwealth indl dev rev rdfg',
#               'prcommonwealth indl dec rev rdfg',
#               'pr commonwealth indl dec rev rdfg',
#               'pr commonwealth indl dev rev r dfg',
#               'pr hsg bk fin agy sing fam mtg',
#               'pr sales tax fing',
#               'pr commonwealth indl dev rev rdfp',
#               'pr commonwealth indl dev rev rfdg',
#               'pr commonwealth indl dev rev rtdg',
#               'pr hsg bk finagy sing fam mtg',
#               'pr commonwealth indl decco rev rdfg',
#               'powershares global exch',
#               'proctor gambill',
#               'pnc bank',
#               'pnc bank ira jg',
#               'pnc bank ira gm',
#               'pnc money market fd',
#               'pitney bowes',
#               'pnc monmarand bond fd',
#               'pnc bond fd',
#               'principal finl group',
#               'pactiv',
#               'petco animal supplies',
#               'protective life',
#               'principal fin group',
#               'principal financial group',
#               'portsmouth va',
#               'property qo value fbo',
#               'property q valuefbo',
#               'pepsicoinc',
#               'pnc bank checking',
#               'prudential financial',
#               'penn va',
#               'pnc tax exempt fund',
#               'penn virginia',
#               'pnc govt fund',
#               'pnc diversified real estate',
#               'parker hannifin',
#               'pharmaceutical product dev',
#               'praxair',
#               'price t rowe group',
#               'pharmaceutical prod dev',
#               'prizer',
#               'pasture crop landtwiggs county georgia',
#               'pasture crop landtwiggs county georgi',
#               'pimco total return mutual fund',
#               'pimco low duration mutual fund',
#               'pnc capital advisors small capcore sma',
#               'pnc capital advisors small cap blend',
#               'pimco total return il',
#               'pnc capita trust e',
#               'petroas intl fin',
#               'peabody energy',
#               'puerto rico ew pa',
#               'petroas intl finco',
#               'phzer fpe',
#               'pnc capital trust e',
#               'p morgan chase',
#               'palm beach school bd',
#               'penn security bank account',
#               'ppl energy supply pfd sr notes',
#               'penn secunty bank account',
#               'port of authority of ny nj',
#               'pearl river ny free school dist',
#               'puerto rico commonwealth',
#               'portof authority of ny nj',
#               'port of authority of ny njo',
#               'puerto ico commonweat',
#               'partnership interest in whitneyhumphrey assc note',
#               'partner cummings drive family lp',
#               'partmership interest in whitneyhumphrey asse note',
#               'philips',
#               'plug power',
#               'petrobank energy res ltdf',
#               'partnership interest in whitneyhumphrey asse note',
#               'petrominerals',
#               'partner cummings drivel” lp',
#               'pax world balance fund',
#               'partner cummings drive family lp note',
#               'pc note',
#               'partner family lp',
#               'petrominerals note',
#               'philips note',
#               'petromineruls note',
#               'partnership interest in whitneyhumphrey asse nowe',
#               'pbhg clipper focus intl',
#               'pedimont natural gas',
#               'property in henderson county tn x',
#               'piedmont natrl gas n c',
#               'parcels of land henderson tn calhoun x',
#               'pedimont natural gas stock',
#               'pinco funds ira',
#               'pimco total return fund',
#               'pimco funds ira',
#               'putnam new opportunity fundvalic',
#               'putnam global gr fundvalic',
#               'piper jaffray prime obligs',
#               'petaquilla minerals ltdfformerly adrian resources',
#               'putnam new opportunties',
#               'phoenixtuson ranch',
#               'paragon shipppng',
#               'petaquilla minerals',
#               'petrohawk energy',
#               'petroleo brasileiro',
#               'potash',
#               'principal financial',
#               'provident energy t',
#               'provident energy',
#               'petaquilla minerals ltdf formerly adrian resources',
#               'provident energytrust',
#               'paragon shipppug prgn',
#               'pepsico pep',
#               'petaquilla mmerals ptqmf',
#               'petrohawk energy hk',
#               'petroleo brasileirod pbr',
#               'punco pty',
#               'potash pot',
#               'principal financial pfg',
#               'provident energy t pvx',
#               'putmam global gr fundvalic',
#               'paragon shipppug prgnl',
#               'performance food group pfgc',
#               'pimco pty',
#               'pimco opp fund pty',
#               'principal finan pfg',
#               'pjt partmers pit',
#               'paragon shipppng prgn',
#               'pembina pipeline pba',
#               'putnam new opportunity fund',
#               'putnam global gr fund',
#               'pjt partners pit',
#               'putnam ncw opportunity fundvalic',
#               'phoenixtuson runch',
#               'petroleo brasileirol pbr',
#               'piunco pty',
#               'plasmatech ptbi formerly known as access accp',
#               'paragon shipppug prgny',
#               'phoemxtuson ranch y'],
#              'm': ['microsoft',
#               'medtronic',
#               'mine safety',
#               'maritrans',
#               'ms active assets taxfree trust',
#               'morgan stanley bank account',
#               'ms global div growth a',
#               'morgan stanley bank',
#               'morgan stanley bank na and private bank na',
#               'morgan stanley active assets acount',
#               'monument bank cds',
#               'mediq preferred stock',
#               'mb bank',
#               'memill lynch account',
#               'metlife lnc com met',
#               'mcdonalds com mcd',
#               'metlife com met',
# ...
#               'va college bldg auth',
#               'viacom',
#               'vanguard index tr',
#               'vanguard total intl stock index',
#               'vanguard utilities index',
#               'varian medical systems',
#               'verisign',
#               'vulcan matls',
#               'va state pub bldg',
#               'va commonwealth univ',
#               'varian med sys',
#               'vulcan materials',
#               'virginia st pub bldg auth',
#               'vanguard index tr small cap',
#               'va st pub bldg auth',
#               'vanguard total intl stock index fnd',
#               'vanguard index tr small cap stock fnd',
#               'valspar',
#               'vornado rlty tr',
#               'vornado rlty trst',
#               'vanguard rei’',
#               'va state',
#               'virginia st pub sch auth',
#               'verizon comm',
#               'vanguard total intl stock ndex',
#               'vanguard growth income fu nd',
#               'vanguard index trust value portfolio',
#               'virginiast',
#               'vca antech',
#               'va college bld',
#               'vanguard total intl stock i ndx',
#               'vanguard total intl stock i ndex',
#               'va coll bldg',
#               'vanguard total intl stock ndex fnd',
#               'vanguard growth income fund',
#               'vanguard total intl stock indx',
#               'vast pub bldg auth',
#               'va beach va',
#               'vehicles',
#               'vanguard reit etf index',
#               'vanguard growth etf msci us prime mkt',
#               'vanguard short term treasury adm',
#               'vanguard crsp us large cap growth ind etf',
#               'vanguard crsp us large cap growth ind ftf',
#               'vale sa vale',
#               'vanguard vti',
#               'vanguard fywix',
#               'vanguard vt',
#               'vasomedical common stock',
#               'virgin island pfa rum tax',
#               'vomado rlty l pnt',
#               'vomado rity l pnt',
#               'vetronoitan rans auth',
#               'vassau cnty yy oncs',
#               'vanguard windsor ii fund',
#               'vanguard global equity fund',
#               'vanguard intl growth fund',
#               'vanguard strategic equity',
#               'vanguard energy fund',
#               'vanguard windsor il fund',
#               'vanguard russell growth index fund iviwgy',
#               'vanguard russell value index fund ivtwv',
#               'vanguard reit value index',
#               'vanguard russell index fund',
#               'vanguard ftse emerging markets',
#               'vanguard small cap fund',
#               'vanguard total stock market',
#               'vanguard mid cap',
#               'vanguard admiral sp value',
#               'vanguard value index',
#               'vanguard windsor iund',
#               'vanguard russell growth index fund',
#               'vanguard russell value index fund',
#               'vanguard reit etf',
#               'vanguard emerging markets',
#               'vanguard scottsdale fds vanguard ivtwvy',
#               'vanguard scottsdale fds vanguard russell ivtwgh',
#               'vanguard index fds vanguard reit vnq',
#               'vanguard russell index fund vthr',
#               'vanguard mid cap vmvix',
#               'vanguard admiral sp value voor',
#               'vanguard value index vivax',
#               'vanguard scottsdale fds vanguard vtwv',
#               'vanguard scottsdale fds vanguard russell vtwg',
#               'vanguard index fds vanguard reitreal estate vnq',
#               'vanguard scottsdale russell vthr note',
#               'vanguard value index vviax',
#               'vanguard wellesley fund',
#               'vanguard gnma fund',
#               'vanguard strategic equity note',
#               'vanguard european fund',
#               'vanguard emerging markets note',
#               'vanguard scottsdale fds vanguard russell vtww nowe',
#               'vanguard scottsdale fds vanguard russell vtwco note',
#               'vanguard index fds vanguard reit vnq note',
#               'vanguard admiral sp s value',
#               'van eck global',
#               'vanguard strategic equity fund',
#               'vanguard scottsdale fds vanguard russell vtwgh',
#               'vanguard index fds vanguard reit vno',
#               'vanguard index fund',
#               'vanguard midcap fund',
#               'vanguard pacific stock index fund',
#               'verizoncommunications com',
#               'vodafone airtouch sp',
#               'vanguard capital apprec',
#               'vanguard gnma ira',
#               'vanguard tax exempt money market',
#               'vanguard international fund',
#               'vanguard stock market index fund',
#               'vanguard precious metals and mining',
#               'vanguard gnma admiral',
#               'vanguard wellington fund adminral',
#               'vanguard dividend growth fund',
#               'vanguard money market ira',
#               'vanguard taxexempt money market',
#               'vanguard gnma',
#               'vanguard life strategy moderate growth fund ira x',
#               'vanguard money market prime fund ira xx',
#               'vanguard gnma fund admiral shares x',
#               'vanguard prime money market fund x',
#               'vanguard life strategy moderate growth fund ira',
#               'vanguard money market prime fund ira',
#               'vanguard gnma fund admiral shares',
#               'vanguard prime money market fund',
#               'vanguard capital appr',
#               'vanguard intemational fund',
#               'van kampen government sec',
#               'van kampen equity income fd cla',
#               'voyageur mut fds del idaho tax freecl a',
#               'voyageur mut fds del mn high yield munibdfdcl a',
#               'voyageur mut fds del mn high yield munibd fd cl a',
#               'voyageur mut fds del mn high yieldmunibdfdcl a',
#               'vankampen ins muni trust',
#               'vankampen select growth fund',
#               'vanguard pacific stock fundnew',
#               'vomado realty trust',
#               'vanguard pacific stock fund',
#               'vanguard total world stock vt',
#               'venzon commumcations vz',
#               'vodafone vod',
#               'venzon communications vz',
#               'vale sa adr vale',
#               'veracyte vcyt',
#               'verastem vstm',
#               'viewray vray',
#               'vodaphone vod',
#               'vanguard vtsmx',
#               'veracytevcyt',
#               'verizon communications vz',
#               'venzon communications',
#               'vanguard vtsax',
#               'van kaawpen ins muni trust',
#               'vankampen ins muni ine trust',
#               'vanguard voo'],
#              'e': ['estate no',
#               'electronic data systems common stock',
#               'electronic data systems common st ock',
#               'exelon',
#               'electronic data system common stock',
#               'exxon mobil com',
#               'exelon comp',
#               'emerson elec',
#               'estate',
#               'estates and see lines',
#               'estate see line',
#               'estate see line $',
#               'estates and',
#               'estate x',
#               'eaton vance enhanced eq',
#               'eaton vance',
#               'eaton vance enhanced equity',
#               'eaton vance ehhanced eqinc',
#               'exxon mobil',
#               'eagle small cap fd',
#               'eagel small cap growth fd',
#               'emerson electric',
#               'equity residential pptys',
#               'entergy com new',
#               'expeditors intl wash',
#               'excelsior belnded equity',
#               'excelsior value restr fund',
#               'entergy new',
#               'expeditors intl washington',
#               'el paso',
#               'emersonelecco',
#               'eog resources',
#               'eogresources',
#               'eagle global advisors intl equity',
#               'equitable life insurance des moines ia variable life',
#               'equitable life insurance des moines ia annuity',
#               'equitable life insurance des moines ja annuity',
#               'equitable life insurance des moines a variable life',
#               'equitable life insurance des moines la annuity',
#               'equitable life insurance des moines a annuity',
#               'equitable life insurance des moines a vanable life',
#               'exco resources',
#               'exco res',
#               'excor hx',
#               'excor',
#               'eastern ill univ rev b',
#               'eastern ill u rev bond',
#               'eastern ill univrevb',
#               'evergreen money market fund',
#               'excelsior value rest fund',
#               'excelsior value rest fund note',
#               'excelsior value rest',
#               'exxonmobil',
#               'exxon mobile',
#               'exxon mobil j»',
#               'exxon mobil carp',
#               'eagle midcap ira',
#               'eaton vance large cap ira',
#               'eagle ser midcap stock fund',
#               'eaton vance large cap fund',
#               'ethel brown ira vanguard total bond mkt fund x',
#               'ethel brown trust vanguard funds x',
#               'ethel brown trust vanguard brokerage account x',
#               'endologix incnew',
#               'electronic arts',
#               'endologix',
#               'exxon mobil corpmerger with xto energy',
#               'energy',
#               'endologix elgx',
#               'equity residentialeqr',
#               'exxon mobile xom',
#               'enbridge energy eep',
#               'exact sciences exas',
#               'enbridge enb',
#               'electronic arts erts now ea',
#               'entegris entg',
#               'european equity fund eea'],
#              'd': ['dreyfus fund',
#               'dreyfus premier third century fundz',
#               'decatur mutual fund',
#               'decatur i mutual fund',
#               'delphi common stock',
#               'decaturl mutual fund',
#               'delphicommon stock',
#               'dominion res new vad',
#               'digital realty tr dlr',
#               'domimion res new vad',
#               'deutsche xtrackers msci eafe hedged eq dbef',
#               'deutsche xtrackers msci eafe hedged fq dbef',
#               'dominion energy',
#               'digital rlty tr',
#               'digital rity tr',
#               'duke energy new',
#               'docto juris common stock',
#               'doctor juris common stock',
#               'docto juris « common stock',
#               'doctor juns common stock',
#               'docto juris inccommon stock',
#               'disciplined tr unit cusip',
#               'disney',
#               'disie',
#               'dominion res',
#               'daktronics',
#               'dow chemical',
#               'devon energy',
#               'dicks sporting goods',
#               'dollar tree stores',
#               'dover com',
#               'dun bradstreet',
#               'deere',
#               'dover',
#               'dc wmata',
#               'dws international fund',
#               'dws international',
#               'dpl com',
#               'donnelley rr sons',
#               'dresser rand group',
#               'drilquip',
#               'drillquip',
#               'dresserrand group',
#               'danaher',
#               'dentsply intl',
#               'dpl inccom',
#               'danville va',
#               'dodge and cox income mutual fund',
#               'dodge cox income',
#               'dwight asset mgmt stb value fund',
#               'dfa twoyear global fixed income mutf',
#               'dfa us large cap value mutf',
#               'dfa large cap international portfolio mutf',
#               'dfa intermediate govt fixedincome mutf',
#               'dfa interm govt fixed income',
#               'dfa fiveyear global fixedincome mutf',
#               'dfa international value',
#               'dfa international value mute',
#               'dfa short term ext quality',
#               'dfa world ex us core equity',
#               'dfa large cap intemational portfolio mutf',
#               'dfa international value mutf',
#               'dfa large cap intemational portfolio mute',
#               'dwight asset mgmt',
#               'duke energy',
#               'db capiual t',
#               'decutsche bk cap ill',
#               'deutsche bk cap',
#               'doubleline dlxnx',
#               'doublelme dltnx',
#               'doublelme dlsnx',
#               'doublelinedltnx',
#               'doubleline dltnx',
#               'dupage cty hsb',
#               'duff phelps glb ltl',
#               'discover fin serv',
#               'deutsche bk cap iii',
#               'duff phelps glb utl',
#               'dade school district be',
#               'discover bank greenwood decd',
#               'discover bank',
#               'doral bk catano pr cd',
#               'duff phelps glb lutljinc',
#               'davis ny venture mutual fund',
#               'discovery hldg common',
#               'dist dear’ vver vy tree sc',
#               'davis nt venture fd a',
#               'dodge cox intl stock',
#               'dodge cox int stock',
#               'dodge cox intl stock note',
#               'dodge cox intl stock fund',
#               'dodge cox stock fund',
#               'delaware pooled tr diversified incomefdcl a',
#               'delaware pooled tr diversified income fdcl a',
#               'deferred comp plan',
#               'dendreon',
#               'dacotah bank x',
#               'deere de',
#               'dendreon dndn',
#               'dupont dd',
#               'deferred comp plan h',
#               'donnelley financial dfin',
#               'doubleline dsl',
#               'dodge cos dodgx',
#               'delta airlines dal',
#               'denburyx',
#               'delta dal',
#               'dana holding dan',
#               'dell dell',
#               'domnelley rrd',
#               'devon energy dvn',
#               'dole dole',
#               'donnelley rrd',
#               'ddr comp',
#               'dendreon dndn y',
#               'diamond trust'],
#              'x': ['x common stock',
#               'xylem',
#               'xtrackers usd high yield bond',
#               'xcel energy',
#               'xys wy auth',
#               'x cl new',
#               'xm satellite radio',
#               'xto energy into exxon',
#               'xcl ld',
#               'xclld',
#               'xerox xrx',
#               'xcllw',
#               'xm satelhite rudo',
#               'xcllwd'],
#              'k': ['kraft the heinz shs khc',
#               'kimberly clark kmb',
#               'kraft the heinz shs',
#               'kimberly clark',
#               'kinder morgan del',
#               'kraneshares csi china',
#               'kimberlyclark',
#               'ky tax exempt money fd',
#               'kv tax exempt money fd',
#               'ky tax ex mon mkt fd',
#               'kinetic concepts',
#               'kimco realty',
#               'kohls',
#               'kayne anderson rudnick inv mgmt small cap core',
#               'k account',
#               'kansas cy clgs',
#               'kkr fin knfrr',
#               'kopp emerging growth fund cl a',
#               'kinder morgan energy kmp'],
#              'y': ['year treasury bond etf ef',
#               'year treasury bond etf ief',
#               'yahoo',
#               'yew yort st invironmenta',
#               'yew yor state',
#               'yy yun wr fin auth',
#               'yyc tea’ th “losnita',
#               'yestchester cnty yy',
#               'yamana gold',
#               'yahoo yhoo',
#               'yamana gold incoo avy',
#               'yeti yeti'],
#              'q': ['qualcomm',
#               'quanta svcs',
#               'quanta services',
#               'quest diagnostics',
#               'questar',
#               'qualcomm qcom',
#               'quanta services pwr',
#               'qorvo qrvo',
#               'qualcom qcom']})

# %%
# Function to calculate similarity scores for party names and investment descriptions

def compare_similarity_scores(party_name, investment_dict):
    first_letter = party_name[0].lower()

    # Get relevant investment descriptions for the first letter
    relevant_investments = investment_dict.get(first_letter, [])

    results = []
    for investment in relevant_investments:
        lev_score = Levenshtein.normalized_similarity(party_name, investment)
        jaro_score = JaroWinkler.similarity(party_name, investment)

        results.append({
            "party_name": party_name,
            "investment": investment,
            "levenshtein_score": lev_score,
            "jaro_winkler_score": jaro_score
        })
    return pd.DataFrame(results).sort_values(by=["levenshtein_score", "jaro_winkler_score"], ascending=False)

# %%
# Test implementation for first 50 party names
party_names_sample = unique_processed_party_names[:50]
start_time = time.time()
results = []
for name in party_names_sample:
    result = compare_similarity_scores(name, processed_investment_dict)
    results.append(result)
end_time = time.time()
print(f'Time taken to process 50 party names is {end_time - start_time} seconds')

# Examine results
results_df = pd.concat(results)
print(results_df.head())
# Out:
# Time taken to process 50 party names is 0.11429715156555176 seconds
#     party_name          investment  levenshtein_score  jaro_winkler_score
# 0      neumont             newmont           0.857143            0.923810
# 58     neumont         newmont mng           0.545455            0.840693
# 149    neumont         newmont nem           0.545455            0.840693
# 77     neumont               nucor           0.428571            0.676190
# 142    neumont  newmont mining nem           0.333333            0.784127

# %%
# Test the top match code
results_df['average_score'] = results_df[['levenshtein_score','jaro_winkler_score']].mean(axis=1)
top_matches = results_df.groupby('party_name').head(1)
top_matches = top_matches.sort_values(by='average_score', ascending=False)
top_matches.head()
print(top_matches.shape)
# Out:
# (50, 5)

# %%
# Implement for all party names

def get_top_match_using_lev_jarowinkler(party_list, investment_dict):
    '''
    Calculate the similarity score for party name, take the average of the two scores and return the top match
    '''
    results = []
    start_time = time.time()
    for name in party_list:
        result = compare_similarity_scores(name, investment_dict)
        results.append(result)
    results_df = pd.concat(results)
    results_df['average_score'] = (results_df['levenshtein_score'] + results_df['jaro_winkler_score']) / 2
    top_match = results_df.groupby('party_name').apply(lambda x: x.loc[x['average_score'].idxmax()])
    end_time = time.time()
    print(f'Time taken to process {len(party_list)} party names is {end_time - start_time:.2f} seconds')
    return top_match

# %%
# Implementation with all party names
top_matches_all = get_top_match_using_lev_jarowinkler(unique_processed_party_names, processed_investment_dict)
print(top_matches_all.shape)
print(top_matches_all)
# Out:
# Time taken to process 2808 party names is 1.67 seconds
# (2808, 5)
#                                                                 party_name  \
# party_name
# aaron transfer storage                              aaron transfer storage
# abbott laboratories                                    abbott laboratories
# abels                                                                abels
# abm janitorial servicesnorth central  abm janitorial servicesnorth central
# academia sagrado corazon                          academia sagrado corazon
# ...                                                                    ...
# zimmerman                                                        zimmerman
# zollinger                                                        zollinger
# zurich america insurance                          zurich america insurance
# zurich american insurance                        zurich american insurance
# zurlo                                                                zurlo
#
#                                                      investment  \
# party_name
# aaron transfer storage                        ann taylor stores
# abbott laboratories                                 abbott labs
# abels                                                 albertson
# abm janitorial servicesnorth central  american airlines grp aal
# academia sagrado corazon                american express common
# ...                                                         ...
# zimmerman                                          zimmer hidgs
# zollinger                                         zarlink mitel
# zurich america insurance                        zimmer holdings
# zurich american insurance                   zimmer holdings com
# zurlo                                              zimmer hldgs
#
#                                       levenshtein_score  jaro_winkler_score  \
# party_name
# aaron transfer storage                         0.500000            0.749251
# abbott laboratories                            0.578947            0.915789
# abels                                          0.444444            0.806667
# abm janitorial servicesnorth central           0.361111            0.738242
# academia sagrado corazon                       0.375000            0.670169
# ...                                                 ...                 ...
# zimmerman                                      0.500000            0.833333
# zollinger                                      0.384615            0.646724
# zurich america insurance                       0.291667            0.594444
# zurich american insurance                      0.280000            0.592749
# zurlo                                          0.250000            0.616667
#
#                                       average_score
# party_name
# aaron transfer storage                     0.624626
# abbott laboratories                        0.747368
# abels                                      0.625556
# abm janitorial servicesnorth central       0.549677
# academia sagrado corazon                   0.522585
# ...                                             ...
# zimmerman                                  0.666667
# zollinger                                  0.515670
# zurich america insurance                   0.443056
# zurich american insurance                  0.436374
# zurlo                                      0.433333
#
# [2808 rows x 5 columns]
# /var/folders/54/mhs5zkcs6zb1_y58hd7pczjc0000gn/T/ipykernel_98290/3884087229.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_match = results_df.groupby('party_name').apply(lambda x: x.loc[x['average_score'].idxmax()])

# %%
top_matches_all.to_csv('top_matches_all.csv', index=False)

# %%
merged_dock_inv_str_matching_v1.to_csv('merged_dock_inv_str_matching_v1.csv', index=False)

# %%
# Drop the party_name index to prepare for merging
top_matches_all = top_matches_all.reset_index(drop=True)

# Merge dataframes based on matching party names and best matches, and also keep = 1
df_result = pd.merge(merged_dock_inv_str_matching_v1, top_matches_all,
                     left_on=['processed_party_name', 'processed_inv_description'],
                     right_on=['party_name', 'investment'],
                     how='left')

# Examine the shape of the merged dataframe
print(df_result.shape)
df_result.head()
# Out:
# (1326520, 12)
#    author_id party_name_x  dateFiled_year_x           inv_description  \
# 0       2490      Neumont              2003             Wachovia Bank
# 1       2490      Neumont              2003  West Palm Beach, Florida
# 2       2490      Neumont              2003     Fidelity Fed. Bk & Tr
# 3       2490      Neumont              2003              COMMON STOCK
# 4       2490      Neumont              2003          Loch Laurel Club
#
#    dateFiled_year_y processed_party_name processed_inv_description  \
# 0              2003              neumont             wachovia bank
# 1              2003              neumont   west palm beach florida
# 2              2003              neumont        fidelity fed bk tr
# 3              2003              neumont              common stock
# 4              2003              neumont          loch laurel club
#
#   party_name_y investment  levenshtein_score  jaro_winkler_score  \
# 0          NaN        NaN                NaN                 NaN
# 1          NaN        NaN                NaN                 NaN
# 2          NaN        NaN                NaN                 NaN
# 3          NaN        NaN                NaN                 NaN
# 4          NaN        NaN                NaN                 NaN
#
#    average_score
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# Filter df_result rows where average_score is not NaN
df_result = df_result[df_result['average_score'].notna()]
print(df_result.shape)
df_result.head()
# Out:
# (380, 12)
#      author_id party_name_x  dateFiled_year_x inv_description  \
# 13        2490      Neumont              2003         Newmont
# 73        2490      Neumont              2003         Newmont
# 130       2490      Neumont              2003         Newmont
# 365       2490      Neumont              2002         Newmont
# 425       2490      Neumont              2002         Newmont
#
#      dateFiled_year_y processed_party_name processed_inv_description  \
# 13               2003              neumont                   newmont
# 73               2005              neumont                   newmont
# 130              2004              neumont                   newmont
# 365              2003              neumont                   newmont
# 425              2005              neumont                   newmont
#
#     party_name_y investment  levenshtein_score  jaro_winkler_score  \
# 13       neumont    newmont           0.857143             0.92381
# 73       neumont    newmont           0.857143             0.92381
# 130      neumont    newmont           0.857143             0.92381
# 365      neumont    newmont           0.857143             0.92381
# 425      neumont    newmont           0.857143             0.92381
#
#      average_score
# 13        0.890476
# 73        0.890476
# 130       0.890476
# 365       0.890476
# 425       0.890476

# %%
df_result.to_csv('string_matching_final_results.csv', index=False)
