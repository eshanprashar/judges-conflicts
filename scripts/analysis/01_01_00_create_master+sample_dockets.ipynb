# %%
# Import libraries
import os
import pandas as pd
import glob
import warnings
import timeit
import ast  # To safely evaluate string representations of lists

# %%
# Read all csv files in data folder and concatenate them into one dataframe
# Define the data folder first
current_path = os.getcwd()
parent_dir = os.path.dirname(current_path)
grandparent_dir = os.path.dirname(parent_dir)
docket_csv_path = os.path.join(grandparent_dir, 'data', 'dockets','individual_csvs')
print(docket_csv_path)
# Out:
# /Users/eshan23/eshanprashar_git_profile/judges-conflicts/data/dockets/individual_csvs

# %%
# Function to read csvs using glob
# Suppress only specific warnings, such as DtypeWarning
warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)

# Defining load_data function
def load_data(data_dir):
    '''
    Base approach to load data from csv files in a directory
    '''
    all_files = glob.glob(data_dir + "/*.csv")
    print(f"Found {len(all_files)} files in the directory")

    # Measure time using timeit
    start_time = timeit.default_timer()

    li = []
    for filename in all_files:
        try:
            df = pd.read_csv(filename, index_col=None, header=0, ) # Turn warnings off 
            li.append(df)
        except Exception as e:
            print(f"Error reading file {filename}: {e}")

    elapsed_time = timeit.default_timer() - start_time
    print(f"Time taken to load {len(all_files)} files using base approach: {elapsed_time:.2f} seconds")
    return pd.concat(li, axis=0, ignore_index=True)

# %%
# Load dockets
df = load_data(docket_csv_path)
# Out:
# Found 1403 files in the directory
# Time taken to load 1403 files using base approach: 5.00 seconds

# %%
# Examine the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194066 entries, 0 to 194065
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   absolute_url                 194066 non-null  object
#  1   attorney                     163967 non-null  object
#  2   caseName                     194066 non-null  object
#  3   caseNameFull                 166072 non-null  object
#  4   citation                     194066 non-null  object
#  5   citeCount                    194066 non-null  int64
#  6   cluster_id                   194066 non-null  int64
#  7   court                        194066 non-null  object
#  8   court_citation_string        194066 non-null  object
#  9   court_id                     194066 non-null  object
#  10  dateArgued                   385 non-null     object
#  11  dateFiled                    194066 non-null  object
#  12  dateReargued                 0 non-null       float64
#  13  dateReargumentDenied         168 non-null     object
#  14  docketNumber                 191957 non-null  object
#  15  docket_id                    194066 non-null  int64
#  16  judge                        194066 non-null  object
#  17  lexisCite                    142290 non-null  object
#  18  meta                         194066 non-null  object
#  19  neutralCite                  1776 non-null    object
#  20  non_participating_judge_ids  194066 non-null  object
#  21  opinions                     194066 non-null  object
#  22  panel_ids                    194066 non-null  object
#  23  panel_names                  194066 non-null  object
#  24  posture                      2503 non-null    object
#  25  procedural_history           0 non-null       float64
#  26  scdb_id                      1862 non-null    object
#  27  sibling_ids                  194066 non-null  object
#  28  source                       194066 non-null  object
#  29  status                       194066 non-null  object
#  30  suitNature                   26586 non-null   object
#  31  syllabus                     238 non-null     object
# dtypes: float64(2), int64(3), object(27)
# memory usage: 47.4+ MB

# %%
# Function to safely extract the 'author_id' and 'snippet' fields
def extract_author_id(opinion):
    if isinstance(opinion, str):
        # Convert string representation of list to a Python object
        opinion = ast.literal_eval(opinion)
    if isinstance(opinion, list) and len(opinion) > 0:
        return opinion[0].get('author_id', None)
    return None

def extract_snippet(opinion):
    if isinstance(opinion, str):
        # Convert string representation of list to a Python object
        opinion = ast.literal_eval(opinion)
    if isinstance(opinion, list) and len(opinion) > 0:
        return opinion[0].get('snippet', None)
    return None

# Apply the functions to extract 'author_id' and 'snippet'
df['author_id'] = df['opinions'].apply(extract_author_id)
df['snippet'] = df['opinions'].apply(extract_snippet)

# %%
# Export this as a csv
df.to_csv(os.path.join(grandparent_dir, 'data', 'dockets/intermediate_dfs', 'all_dockets_judges_w_fin_dis.csv'), index=False)

# %%
# Examine count of unique docket_id by author_id
df.groupby('author_id')['docket_id'].nunique().sort_values(ascending=False)
# Out:
# author_id
# 1844    2098
# 1124    1828
# 201     1666
# 1911    1601
# 3150    1483
#         ...
# 807        1
# 2371       1
# 2374       1
# 2385       1
# 2228       1
# Name: docket_id, Length: 1403, dtype: int64

# %%
# Create bins for docket counts
bins = [0, 5, 10, 50, 100, 250,500,750,1000,1250,1500,1750,2000,2500]

# Function to assign bin to each row based on unique docket ids for author_id
def assign_bin(docket_count):
    for i in range(len(bins)-1):
        if docket_count >= bins[i] and docket_count < bins[i+1]:
            return f"{bins[i]}-{bins[i+1]-1}"
    return f">{bins[-1]}"

# Apply the function to create a new column 'docket_count_bin'
df['docket_count_bin'] = df.groupby('author_id')['docket_id'].transform('nunique').apply(assign_bin)

# Examine the dataframe
df.head()
# Out:
#                                         absolute_url  \
# 0  /opinion/2182594/garcia-v-nationwide-mutual-in...
# 1  /opinion/2579421/scarpulla-v-bayer-corp-disabi...
# 2     /opinion/2578911/chazen-v-deloitte-touche-llp/
# 3  /opinion/2573917/state-farm-fire-casualty-co-v...
# 4      /opinion/2565101/american-canoe-assn-v-white/
#
#                                             attorney  \
# 0  Richard H. Honaker, Honaker Law Offices, Rock ...
# 1  Jeffrey S. Daniel, Birmingham, AL, for Plainti...
# 2  James L. North, J. Timothy Francis, James L. N...
# 3  David A. Pote, James C. Gray, III, Lloyd Gray ...
# 4  Ray Vaughan, WildLaw, Montgomery, David Bookbi...
#
#                                      caseName  \
# 0       Garcia v. Nationwide Mutual Insurance
# 1    Scarpulla v. Bayer Corp. Disability Plan
# 2            Chazen v. Deloitte & Touche, LLP
# 3  State Farm Fire & Casualty Co. v. Knoblett
# 4               American Canoe Ass'n v. White
#
#                                         caseNameFull  \
# 0  Michael GARCIA, Plaintiff, v. NATIONWIDE MUTUA...
# 1  Teresa SCARPULLA, Plaintiffs, v. BAYER CORPORA...
# 2  Stephen M. CHAZEN, Plaintiff, v. DELOITTE & TO...
# 3  STATE FARM FIRE & CASUALTY CO., Plaintiff, v. ...
# 4  AMERICAN CANOE ASSOCIATION, Et Al., Plaintiffs...
#
#                                             citation  citeCount  cluster_id  \
# 0  ['821 F. Supp. 2d 1264', '2011 U.S. Dist. LEXI...          0     2182594
# 1        ['514 F. Supp. 2d 1262', '2007 WL 2800369']          0     2579421
# 2  ['247 F. Supp. 2d 1259', '2003 U.S. Dist. LEXI...          3     2578911
# 3  ['561 F. Supp. 2d 1256', '2008 U.S. Dist. LEXI...          1     2573917
# 4       ['277 F. Supp. 2d 1244', '2003 WL 21982008']          3     2565101
#
#                           court court_citation_string court_id  ...  \
# 0    District Court, D. Wyoming               D. Wyo.      wyd  ...
# 1  District Court, N.D. Alabama             N.D. Ala.     alnd  ...
# 2  District Court, N.D. Alabama             N.D. Ala.     alnd  ...
# 3  District Court, N.D. Alabama             N.D. Ala.     alnd  ...
# 4  District Court, N.D. Alabama             N.D. Ala.     alnd  ...
#
#   procedural_history scdb_id  sibling_ids source     status  suitNature  \
# 0                NaN     NaN    [2182594]     LU  Published         NaN
# 1                NaN     NaN    [2579421]     LU  Published         NaN
# 2                NaN     NaN    [2578911]     LU  Published         NaN
# 3                NaN     NaN    [2573917]     LU  Published         NaN
# 4                NaN     NaN    [2565101]     LU  Published         NaN
#
#   syllabus author_id                                            snippet  \
# 0      NaN      2986  \n821 F.Supp.2d 1264 (2011)\nMichael GARCIA, P...
# 1      NaN       341  \n514 F.Supp.2d 1262 (2007)\nTeresa SCARPULLA,...
# 2      NaN       341  \n247 F.Supp.2d 1259 (2003)\nStephen M. CHAZEN...
# 3      NaN       341  \n(2008)\nSTATE FARM FIRE & CASUALTY CO., Plai...
# 4      NaN       341  \n277 F.Supp.2d 1244 (2003)\nAMERICAN CANOE AS...
#
#   docket_count_bin
# 0              0-4
# 1            10-49
# 2            10-49
# 3            10-49
# 4            10-49
#
# [5 rows x 35 columns]

# %%
# Get counts of author_id by docket_count_bin
df.groupby('docket_count_bin')['author_id'].nunique().sort_values(ascending=False)
# Out:
# docket_count_bin
# 10-49        376
# 100-249      347
# 50-99        319
# 250-499      115
# 0-4          104
# 5-9           62
# 500-749       48
# 750-999       16
# 1250-1499      8
# 1000-1249      4
# 1500-1749      2
# 1750-1999      1
# 2000-2499      1
# Name: author_id, dtype: int64

# %%
# We will select 25 random authors with more than 100 unique dockets but less than 500
# Random seed for reproducibility
random_seed = 42

# Define buckets to filter from
bucket = ['100-249', '250-499', '500-749']

# Filter authors with docket counts in the category 100-249 and 250-499
author_ids = df[df['docket_count_bin'].isin(bucket)]['author_id'].unique()

# Define number of authors to select 
num_authors = 25

# Randomly select 20 authors
selected_authors = pd.Series(author_ids).sample(num_authors, random_state=random_seed).values

# Filter the dataframe for selected authors
df_sampled = df[df['author_id'].isin(selected_authors)]

# Examine the dataframe
print(f"Size of sampled dataframe is {df_sampled.shape}")
df_sampled.head()
# Out:
# Size of sampled dataframe is (5913, 35)
#                                            absolute_url  \
# 3550  /opinion/2596484/watchorn-ex-rel-christenson-v...
# 3551  /opinion/2512315/dictiomatic-inc-v-united-stat...
# 3552  /opinion/2503927/neumont-v-monroe-county-florida/
# 3553     /opinion/2501892/brandt-v-weather-channel-inc/
# 3554  /opinion/2501376/neumont-v-monroe-county-florida/
#
#                                                attorney  \
# 3550  William R. Amlong, Amlong & Amlong, P.A., Fort...
# 3551  John Joseph Pappas, Butler Burnette & Pappas, ...
# 3552  James H. Hicks, Hicks, Brams & Scher, West Pal...
# 3553  Robert Lamar Bell, Miami, FL, for plaintiffs.,...
# 3554  Harold E. Wolfe, Jr., Eric M. Grant, LeBoeuf, ...
#
#                                                caseName  \
# 3550      Watchorn Ex Rel. Christenson v. Town of Davie
# 3551  Dictiomatic, Inc. v. United States Fidelity & ...
# 3552                   Neumont v. Monroe County Florida
# 3553                    Brandt v. Weather Channel, Inc.
# 3554                  Neumont v. Monroe County, Florida
#
#                                            caseNameFull  \
# 3550  Christina Elisabeth WATCHORN, a Minor, by and ...
# 3551  DICTIOMATIC, INC., a Florida Corporation, and ...
# 3552  Elizabeth J. NEUMONT, Et Al., Plaintiffs, v. M...
# 3553  Deborah K. BRANDT, Et Al., Plaintiff, v. the W...
# 3554  Elizabeth J. NEUMONT, Et Al., Plaintiffs, v. M...
#
#                                                citation  citeCount  \
# 3550  ['795 F. Supp. 1112', '1992 U.S. Dist. LEXIS 1...          5
# 3551  ['127 F. Supp. 2d 1239', '1999 U.S. Dist. LEXI...          1
# 3552  ['104 F. Supp. 2d 1368', '2000 U.S. Dist. LEXI...          1
# 3553  ['42 F. Supp. 2d 1344', '27 Media L. Rep. (BNA...          2
# 3554  ['280 F. Supp. 2d 1367', '2003 U.S. Dist. LEXI...          1
#
#       cluster_id                         court court_citation_string court_id  \
# 3550     2596484  District Court, S.D. Florida             S.D. Fla.     flsd
# 3551     2512315  District Court, S.D. Florida             S.D. Fla.     flsd
# 3552     2503927  District Court, S.D. Florida             S.D. Fla.     flsd
# 3553     2501892  District Court, S.D. Florida             S.D. Fla.     flsd
# 3554     2501376  District Court, S.D. Florida             S.D. Fla.     flsd
#
#       ... procedural_history scdb_id  sibling_ids source     status  \
# 3550  ...                NaN     NaN    [2596484]     LU  Published
# 3551  ...                NaN     NaN    [2512315]     LU  Published
# 3552  ...                NaN     NaN    [2503927]     LU  Published
# 3553  ...                NaN     NaN    [2501892]     LU  Published
# 3554  ...                NaN     NaN    [2501376]     LU  Published
#
#       suitNature syllabus author_id  \
# 3550         NaN      NaN      2490
# 3551         NaN      NaN      2490
# 3552         NaN      NaN      2490
# 3553         NaN      NaN      2490
# 3554         NaN      NaN      2490
#
#                                                 snippet docket_count_bin
# 3550  \n795 F.Supp. 1112 (1992)\nChristina Elisabeth...          100-249
# 3551  \n127 F.Supp.2d 1239 (1999)\nDICTIOMATIC, INC....          100-249
# 3552  \n104 F.Supp.2d 1368 (2000)\nElizabeth J. NEUM...          100-249
# 3553  \n42 F.Supp.2d 1344 (1999)\nDeborah K. BRANDT,...          100-249
# 3554  \n280 F.Supp.2d 1367 (2003)\nElizabeth J. NEUM...          100-249
#
# [5 rows x 35 columns]

# %%
# Get counts of author_id by docket_count_bin
df_sampled.groupby('docket_count_bin')['author_id'].nunique().sort_values(ascending=False)
# Out:
# docket_count_bin
# 100-249    18
# 250-499     5
# 500-749     2
# Name: author_id, dtype: int64

# %%
# Save this dataframe to a parquet file
# Define the path to save the parquet file
docket_path = os.path.join(grandparent_dir, 'data', 'dockets','intermediate_dfs')
#print(docket_path)

# Save the dataframe to a parquet file
df_sampled.to_parquet(os.path.join(docket_path, 'sampled_judges.parquet'))

# %%
# Export the dataframe also as a csv for quick look
df_sampled.to_csv('sampled_dockets.csv', index=False)

# %%
# Also export the list of selected authors to a csv file
pd.DataFrame(selected_authors, columns=['author_id']).to_csv(os.path.join(docket_path, 'sampled_judge_ids.csv'), index=False)
