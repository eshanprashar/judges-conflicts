# %%
# Importing libraries
import requests
import json
import csv
import string
from utils import api_token

# %%
# Function to create a session with the API token
def make_session():
    s = requests.session()
    s.headers.update({"Authorization": f"Token {api_token}"})
    return s

# %%
# Function to fetch data from the API endpoint with pagination handling for a limited number of pages
def fetch_data(url,start_page,max_pages):
    session = make_session()
    all_data = []
    page_count = 0
    
    while url and page_count < max_pages:
        response = session.get(url)
        
        if response.status_code != 200:
            print(f"Error: {response.status_code}, {response.text}")
            break
        
        data = response.json()
        all_data.extend(data['results']) # append data from the current page to the list

        if 'next' in data and data['next'] is not None: # next is the key for the next page
            url = data['next']
            page_count += 1
        else:
            break
    
    # testing: save data to a json file
    with open('testing_data_fetch.json', 'w') as f:
        json.dump(all_data, f)
    
    print(f"Total number of pages fetched: {page_count} starting from page {start_page}")
    return url, all_data

# %%
# Function to process and flatten the data
def process_data(data):
    processed_data = []  # processed data is a list of elements
    for item in data:  # data is the list of "results" from the API response; each item in the list is a dictionary of financial disclosures

        # Extract general fields
        base_entry = {
            'person_url': item['person'],
            'person_id': item['person'].rstrip('/').split('/')[-1],  # last element of the person url gives ID
            'filepath': item['filepath'], # url of the pdf of the disclosure
            'disclosure_year': item['year'],
            'notes': item['addendum_content_raw'],
            'date_created': item['date_created'],
            'date_modified': item['date_modified'],
        }

        # Process agreements
        for agreement in item['agreements']:
            entry = base_entry.copy()
            entry.update({
                'type': 'agreement',
                'agreement_id': agreement.get('id', None),
                'agree_date_raw': agreement.get('date_raw', None),
                'parties_and_terms': agreement.get('parties_and_terms', None),
                'agree_redacted': agreement.get('redacted', None)
            })
            processed_data.append(entry)
        
        # Process gifts
        for gift in item['gifts']:
            entry = base_entry.copy()
            entry.update({
                'type': 'gift',
                'gift_id': gift.get('id', None),
                'gift_source': gift.get('source', None),
                'gift_description': gift.get('description', None),
                'gift_value': gift.get('value', None),
                'gift_redacted': gift.get('redacted', None)
            })
            processed_data.append(entry)

        # Process investments
        for investment in item['investments']:
            entry = base_entry.copy()
            entry.update({
                'type': 'investment',
                'investment_id': investment.get('id', None),
                'inv_description': investment.get('description', None),
                'inv_redacted': investment.get('redacted', None),
                'income_during_reporting_period_code': investment.get('income_during_reporting_period_code', None),
                'income_during_reporting_period_type': investment.get('income_during_reporting_period_type', None),
                'gross_value_code': investment.get('gross_value_code', None),
                'gross_value_method': investment.get('gross_value_method', None),
                'transaction_during_reporting_period': investment.get('transaction_during_reporting_period', None),
                'transaction_date_raw': investment.get('transaction_date_raw', None),
                'transaction_date': investment.get('transaction_date', None),
                'transaction_value_code': investment.get('transaction_value_code', None),
                'transaction_gain_code': investment.get('transaction_gain_code', None),
                'transaction_partner': investment.get('transaction_partner', None),
                'inv_has_inferred_values': investment.get('has_inferred_values', None)
            })
            processed_data.append(entry)

        # Process non-investment incomes
        for non_investment_income in item['non_investment_incomes']:
            entry = base_entry.copy()
            entry.update({
                'type': 'non_investment_income',
                'non_investment_income_id': non_investment_income.get('id', None),
                'non_inv_date_raw': non_investment_income.get('date_raw', None),
                'non_inv_source_type': non_investment_income.get('source_type', None),
                'non_inv_income_amount': non_investment_income.get('income_amount', None),
                'non_inv_redacted': non_investment_income.get('redacted', None)
            })
            processed_data.append(entry)
        
        # Process positions if they exist
        for position in item['positions']:
            entry = base_entry.copy()
            entry.update({
                'type': 'position',
                'position_id': position.get('id', None),
                'position': position.get('position', None),
                'organization_name': position.get('organization_name', None),
                'position_date_raw': position.get('date_raw', None), # this column doesn't exist - but no harm done
                'position_redacted': position.get('redacted', None)
            })
            processed_data.append(entry)

        # Process reimbursements
        for reimbursement in item['reimbursements']:
            entry = base_entry.copy()
            entry.update({
                'type': 'reimbursement',
                'reimbursement_id': reimbursement.get('id', None),
                'reimb_source': reimbursement.get('source', None),
                'reimb_date_raw': reimbursement.get('date_raw', None),
                'reimb_location': reimbursement.get('location', None),
                'purpose': reimbursement.get('purpose', None),
                'items_paid_or_provided': reimbursement.get('items_paid_or_provided', None),
                'reimb_redacted': reimbursement.get('redacted', None)
            })
            processed_data.append(entry)

        # Process spouse incomes
        for spouse_income in item['spouse_incomes']:
            entry = base_entry.copy()
            entry.update({
                'type': 'spouse_income',
                'spouse_income_id': spouse_income.get('id', None),
                'sp_inc_source_type': spouse_income.get('source_type', None),
                'sp_inc_date_raw': spouse_income.get('date_raw', None),
                'sp_inc_redacted': spouse_income.get('redacted', None)
            })
            processed_data.append(entry)
    print(f"Total number of entries processed: {len(processed_data)}")
    return processed_data

# %%
# Function to save the data to a CSV file
def save_to_csv(data, filename):
    with open(filename, 'w', newline='') as csvfile:
        fieldnames = [ # 8 categories of fields: general, agreements, investments, non-investment incomes, positions, reimbursements, spouse incomes 
            'person_id', 'person_url', 'filepath', 'disclosure_year', 'notes', 'date_created', 'date_modified', # general fields
            'type', 'agreement_id', 'agree_date_raw', 'parties_and_terms','agree_redacted',  # agreement fields
            'gift_id', 'gift_source', 'gift_description', 'gift_value', 'gift_redacted', # gift fields

            'investment_id','inv_description', 'inv_redacted', 'income_during_reporting_period_code', 'income_during_reporting_period_type', # investment fields
            'gross_value_code', 'gross_value_method', 'transaction_during_reporting_period', 'transaction_date_raw',
            'transaction_date', 'transaction_value_code', 'transaction_gain_code', 'transaction_partner','inv_has_inferred_values',

            'non_investment_income_id', 'non_inv_date_raw', 'non_inv_source_type', 'non_inv_income_amount', 'non_inv_redacted', # non-investment income fields
            'position_id', 'position', 'organization_name', 'date_raw_position', 'position_redacted', # position fields # date_raw_position doesn't exist in the data
            'reimbursement_id', 'reimb_source', 'date_raw_reimb', 'reimb_location', 'reimb_purpose', 'items_paid_or_provided','reimb_redacted', # reimbursement fields # date_raw_reimb doesn't exist in the data
            'spouse_income_id', 'sp_inc_source_type','sp_inc_date_raw', 'sp_inc_redacted' # spouse income fields
        ]
        
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        
        for row in data:
            # Use dictionary comprehension to handle missing keys by setting them to None
            writer.writerow({field: row.get(field, None) for field in fieldnames})
        print(f"Data saved to {filename}")

# %%
# Fetch and process data for the first 5 pages
base_url = "https://www.courtlistener.com/api/rest/v4/financial-disclosures/" # updated the API to v4 from v3

# For financial disclosures, we know there are 1617 pages of data in CourtListener API
# Since one financial disclosure has a lot of data, we will fetch only 30 pages of data per csv file
start_page = 1
max_pages = 30 # maximum number of pages to fetch
while start_page <= 1620: #1620 is the maximum number of pages
    url = base_url
    base_url, data = fetch_data(url,start_page, max_pages)
    processed_data = process_data(data)
    save_to_csv(processed_data, f"fin_disc_{start_page}-{start_page + max_pages}.csv")
    print(f"Fetched, processed and saved data for pages {start_page} to {start_page + max_pages}!")
    start_page += max_pages
# Out:
# Total number of pages fetched: 30 starting from page 1
# Total number of entries processed: 92123
# Data saved to fin_disc_1-31.csv
# Fetched, processed and saved data for pages 1 to 31!
# Total number of pages fetched: 30 starting from page 31
# Total number of entries processed: 86016
# Data saved to fin_disc_31-61.csv
# Fetched, processed and saved data for pages 31 to 61!
# Total number of pages fetched: 30 starting from page 61
# Total number of entries processed: 46963
# Data saved to fin_disc_61-91.csv
# Fetched, processed and saved data for pages 61 to 91!
# Total number of pages fetched: 30 starting from page 91
# Total number of entries processed: 44565
# Data saved to fin_disc_91-121.csv
# Fetched, processed and saved data for pages 91 to 121!
# Total number of pages fetched: 30 starting from page 121
# Total number of entries processed: 3176
# Data saved to fin_disc_121-151.csv
# Fetched, processed and saved data for pages 121 to 151!
# Total number of pages fetched: 30 starting from page 151
# Total number of entries processed: 22687
# Data saved to fin_disc_151-181.csv
# Fetched, processed and saved data for pages 151 to 181!
# Total number of pages fetched: 30 starting from page 181
# Total number of entries processed: 42204
# Data saved to fin_disc_181-211.csv
# Fetched, processed and saved data for pages 181 to 211!
# Total number of pages fetched: 30 starting from page 211
# Total number of entries processed: 37763
# Data saved to fin_disc_211-241.csv
# Fetched, processed and saved data for pages 211 to 241!
# Total number of pages fetched: 30 starting from page 241
# Total number of entries processed: 38933
# Data saved to fin_disc_241-271.csv
# Fetched, processed and saved data for pages 241 to 271!
# Total number of pages fetched: 30 starting from page 271
# Total number of entries processed: 60174
# Data saved to fin_disc_271-301.csv
# Fetched, processed and saved data for pages 271 to 301!
# Total number of pages fetched: 30 starting from page 301
# Total number of entries processed: 27075
# Data saved to fin_disc_301-331.csv
# Fetched, processed and saved data for pages 301 to 331!
# Total number of pages fetched: 30 starting from page 331
# Total number of entries processed: 32010
# Data saved to fin_disc_331-361.csv
# Fetched, processed and saved data for pages 331 to 361!
# Total number of pages fetched: 30 starting from page 361
# Total number of entries processed: 33057
# Data saved to fin_disc_361-391.csv
# Fetched, processed and saved data for pages 361 to 391!
# Total number of pages fetched: 30 starting from page 391
# Total number of entries processed: 27314
# Data saved to fin_disc_391-421.csv
# Fetched, processed and saved data for pages 391 to 421!
# Total number of pages fetched: 30 starting from page 421
# Total number of entries processed: 29096
# Data saved to fin_disc_421-451.csv
# Fetched, processed and saved data for pages 421 to 451!
# Total number of pages fetched: 30 starting from page 451
# Total number of entries processed: 29238
# Data saved to fin_disc_451-481.csv
# Fetched, processed and saved data for pages 451 to 481!
# Total number of pages fetched: 30 starting from page 481
# Total number of entries processed: 30961
# Data saved to fin_disc_481-511.csv
# Fetched, processed and saved data for pages 481 to 511!
# Total number of pages fetched: 30 starting from page 511
# Total number of entries processed: 29769
# Data saved to fin_disc_511-541.csv
# Fetched, processed and saved data for pages 511 to 541!
# Total number of pages fetched: 30 starting from page 541
# Total number of entries processed: 29351
# Data saved to fin_disc_541-571.csv
# Fetched, processed and saved data for pages 541 to 571!
# Total number of pages fetched: 30 starting from page 571
# Total number of entries processed: 31478
# Data saved to fin_disc_571-601.csv
# Fetched, processed and saved data for pages 571 to 601!
# Total number of pages fetched: 30 starting from page 601
# Total number of entries processed: 44144
# Data saved to fin_disc_601-631.csv
# Fetched, processed and saved data for pages 601 to 631!
# Total number of pages fetched: 30 starting from page 631
# Total number of entries processed: 48306
# Data saved to fin_disc_631-661.csv
# Fetched, processed and saved data for pages 631 to 661!
# Total number of pages fetched: 30 starting from page 661
# Total number of entries processed: 20298
# Data saved to fin_disc_661-691.csv
# Fetched, processed and saved data for pages 661 to 691!
# Total number of pages fetched: 30 starting from page 691
# Total number of entries processed: 42558
# Data saved to fin_disc_691-721.csv
# Fetched, processed and saved data for pages 691 to 721!
# Total number of pages fetched: 30 starting from page 721
# Total number of entries processed: 40069
# Data saved to fin_disc_721-751.csv
# Fetched, processed and saved data for pages 721 to 751!
# Total number of pages fetched: 30 starting from page 751
# Total number of entries processed: 41128
# Data saved to fin_disc_751-781.csv
# Fetched, processed and saved data for pages 751 to 781!
# Total number of pages fetched: 30 starting from page 781
# Total number of entries processed: 43330
# Data saved to fin_disc_781-811.csv
# Fetched, processed and saved data for pages 781 to 811!
# Total number of pages fetched: 30 starting from page 811
# Total number of entries processed: 37565
# Data saved to fin_disc_811-841.csv
# Fetched, processed and saved data for pages 811 to 841!
# Total number of pages fetched: 30 starting from page 841
# Total number of entries processed: 41947
# Data saved to fin_disc_841-871.csv
# Fetched, processed and saved data for pages 841 to 871!
# Total number of pages fetched: 30 starting from page 871
# Total number of entries processed: 36777
# Data saved to fin_disc_871-901.csv
# Fetched, processed and saved data for pages 871 to 901!
# Total number of pages fetched: 30 starting from page 901
# Total number of entries processed: 37859
# Data saved to fin_disc_901-931.csv
# Fetched, processed and saved data for pages 901 to 931!
# Total number of pages fetched: 30 starting from page 931
# Total number of entries processed: 37794
# Data saved to fin_disc_931-961.csv
# Fetched, processed and saved data for pages 931 to 961!
# Total number of pages fetched: 30 starting from page 961
# Total number of entries processed: 33943
# Data saved to fin_disc_961-991.csv
# Fetched, processed and saved data for pages 961 to 991!
# Total number of pages fetched: 30 starting from page 991
# Total number of entries processed: 34404
# Data saved to fin_disc_991-1021.csv
# Fetched, processed and saved data for pages 991 to 1021!
# Total number of pages fetched: 30 starting from page 1021
# Total number of entries processed: 34933
# Data saved to fin_disc_1021-1051.csv
# Fetched, processed and saved data for pages 1021 to 1051!
# Total number of pages fetched: 30 starting from page 1051
# Total number of entries processed: 37274
# Data saved to fin_disc_1051-1081.csv
# Fetched, processed and saved data for pages 1051 to 1081!
# Total number of pages fetched: 30 starting from page 1081
# Total number of entries processed: 39347
# Data saved to fin_disc_1081-1111.csv
# Fetched, processed and saved data for pages 1081 to 1111!
# Total number of pages fetched: 30 starting from page 1111
# Total number of entries processed: 34879
# Data saved to fin_disc_1111-1141.csv
# Fetched, processed and saved data for pages 1111 to 1141!
# Total number of pages fetched: 30 starting from page 1141
# Total number of entries processed: 39003
# Data saved to fin_disc_1141-1171.csv
# Fetched, processed and saved data for pages 1141 to 1171!
# Total number of pages fetched: 30 starting from page 1171
# Total number of entries processed: 41512
# Data saved to fin_disc_1171-1201.csv
# Fetched, processed and saved data for pages 1171 to 1201!
# Total number of pages fetched: 30 starting from page 1201
# Total number of entries processed: 41352
# Data saved to fin_disc_1201-1231.csv
# Fetched, processed and saved data for pages 1201 to 1231!
# Total number of pages fetched: 30 starting from page 1231
# Total number of entries processed: 38237
# Data saved to fin_disc_1231-1261.csv
# Fetched, processed and saved data for pages 1231 to 1261!
# Total number of pages fetched: 30 starting from page 1261
# Total number of entries processed: 37742
# Data saved to fin_disc_1261-1291.csv
# Fetched, processed and saved data for pages 1261 to 1291!
# Total number of pages fetched: 30 starting from page 1291
# Total number of entries processed: 39457
# Data saved to fin_disc_1291-1321.csv
# Fetched, processed and saved data for pages 1291 to 1321!
# Total number of pages fetched: 30 starting from page 1321
# Total number of entries processed: 35121
# Data saved to fin_disc_1321-1351.csv
# Fetched, processed and saved data for pages 1321 to 1351!
# Total number of pages fetched: 30 starting from page 1351
# Total number of entries processed: 39307
# Data saved to fin_disc_1351-1381.csv
# Fetched, processed and saved data for pages 1351 to 1381!
# Total number of pages fetched: 30 starting from page 1381
# Total number of entries processed: 40327
# Data saved to fin_disc_1381-1411.csv
# Fetched, processed and saved data for pages 1381 to 1411!
# Total number of pages fetched: 30 starting from page 1411
# Total number of entries processed: 40922
# Data saved to fin_disc_1411-1441.csv
# Fetched, processed and saved data for pages 1411 to 1441!
# Total number of pages fetched: 30 starting from page 1441
# Total number of entries processed: 36920
# Data saved to fin_disc_1441-1471.csv
# Fetched, processed and saved data for pages 1441 to 1471!
# Total number of pages fetched: 30 starting from page 1471
# Total number of entries processed: 39451
# Data saved to fin_disc_1471-1501.csv
# Fetched, processed and saved data for pages 1471 to 1501!
# Total number of pages fetched: 30 starting from page 1501
# Total number of entries processed: 42097
# Data saved to fin_disc_1501-1531.csv
# Fetched, processed and saved data for pages 1501 to 1531!
# Total number of pages fetched: 30 starting from page 1531
# Total number of entries processed: 35675
# Data saved to fin_disc_1531-1561.csv
# Fetched, processed and saved data for pages 1531 to 1561!
# Total number of pages fetched: 30 starting from page 1561
# Total number of entries processed: 7677
# Data saved to fin_disc_1561-1591.csv
# Fetched, processed and saved data for pages 1561 to 1591!
# Total number of pages fetched: 26 starting from page 1591
# Total number of entries processed: 4443
# Data saved to fin_disc_1591-1621.csv
# Fetched, processed and saved data for pages 1591 to 1621!
